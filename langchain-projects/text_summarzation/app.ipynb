# %%
import os 
from dotenv import load_dotenv
from langchain.schema import AIMessage, HumanMessage, SystemMessage

# %%
speech = """
Deep Neural Networks (DNNs) are powerful models that have achieved excel- lent performance on difficult learning tasks. Although DNNs work well whenever large labeled training sets are available, they cannot be used to map sequences to sequences. In this paper, we present a general end-to-end approach to sequence learning that makes minimal assumptions on the sequence structure. Our method uses a multilayered Long Short-Term Memory (LSTM) to map the input sequence to a vector of a fixed dimensionality, and then another deep LSTM to decode the target sequence from the vector. Our main result is that on an English to French translation task from the WMT’14 dataset, the translations produced by the LSTM achieve a BLEU score of 34.8 on the entire test set, where the LSTM’s BLEU score was penalized on out-of-vocabulary words. Additionally, the LSTM did not have difficulty on long sentences. For comparison, a phrase-based SMT system achieves a BLEU score of 33.3 on the same dataset. When we used the LSTM to rerank the 1000 hypotheses produced by the aforementioned SMT system, its BLEU score increases to 36.5, which is close to the previous best result on this task. The LSTM also learned sensible phrase and sentence representations that are sensitive to word order and are relatively invariant to the active and the pas- sive voice. Finally, we found that reversing the order of the words in all source sentences (but not target sentences) improved the LSTM’s performance markedly, because doing so introduced many short term dependencies between the source and the target sentence which made the optimization problem easier.
1 Introduction
Deep Neural Networks (DNNs) are extremely powerful machine learning models that achieve ex- cellent performance on difficult problems such as speech recognition [13, 7] and visual object recog- nition [19, 6, 21, 20]. DNNs are powerful because they can perform arbitrary parallel computation for a modest number of steps. A surprising example of the power of DNNs is their ability to sort N N -bit numbers using only 2 hidden layers of quadratic size [27]. So, while neural networks are related to conventional statistical models, they learn an intricate computation. Furthermore, large DNNs can be trained with supervised backpropagation whenever the labeled training set has enough information to specify the network’s parameters. Thus, if there exists a parameter setting of a large DNN that achieves good results (for example, because humans can solve the task very rapidly), supervised backpropagation will find these parameters and solve the problem.
Despite their flexibility and power, DNNs can only be applied to problems whose inputs and targets can be sensibly encoded with vectors of fixed dimensionality. It is a significant limitation, since many important problems are best expressed with sequences whose lengths are not known a-priori. For example, speech recognition and machine translation are sequential problems. Likewise, ques- tion answering can also be seen as mapping a sequence of words representing the question to a
"""

chat_message = [
    SystemMessage(
        content="You are a helpful assistant that is expert in text summarization."
        ),
    HumanMessage(
        content=f"Please provide the summary of the following text: {speech}"
    )
]

# %%
from langchain_groq import ChatGroq

# %%
load_dotenv()
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")
llm = ChatGroq(
    groq_api_key=os.environ["GROQ_API_KEY"],
    model="Llama3-8b-8192",
    streaming=True,
    )

# %%
llm.get_num_tokens(text)
# Out:
# 653

# %%
llm(chat_message)
# Out:
# AIMessage(content="Here is a summary of the text:\n\nThe paper presents a new approach to sequence learning using deep neural networks (DNNs) that can map sequences to sequences. The method uses two layers of Long Short-Term Memory (LSTM) networks to transform the input sequence into a fixed-dimensional vector and then decode the target sequence from the vector. The approach is tested on an English-to-French translation task and achieves a BLEU score of 34.8 on the entire test set. This is comparable to a phrase-based statistical machine translation (SMT) system, and even better when the LSTM is used to rerank the hypotheses produced by the SMT system. The LSTM also learns sensible phrase and sentence representations that are sensitive to word order and relatively invariant to the active and passive voice. The authors found that reversing the order of the words in the source sentences improved the LSTM's performance, suggesting that the model benefits from short-term dependencies between the source and target sentences.", additional_kwargs={}, response_metadata={'finish_reason': 'stop', 'model_name': 'Llama3-8b-8192', 'system_fingerprint': 'fp_a97cfe35ae'}, id='run-e5420e2e-009c-44bb-9500-829d82752d4c-0', usage_metadata={'input_tokens': 661, 'output_tokens': 196, 'total_tokens': 857})

# %%
## Prompt template

from langchain.chains import LLMChain
from langchain.prompts import PromptTemplate

# %%
generic_prompt_template = """"
Write a summary of the following text:
Text: {text},
Translate the summary to {language}:
"""

# %%
prompt = PromptTemplate(
    input_variables=["text", "language"],
    template=generic_prompt_template
)

# %%
prompt
# Out:
# PromptTemplate(input_variables=['language', 'text'], input_types={}, partial_variables={}, template='"\nWrite a summary of the following text:\nText: {text},\nTranslate the summary to {language}:\n')

# %%
complete_prompt = prompt.format(
    text = speech,
    language="hindi",
)

# %%
llm.get_num_tokens(complete_prompt)
# Out:
# 678

# %%
llm_chain = LLMChain(llm=llm, prompt=prompt)
summary = llm_chain.run(
    {
        "text":speech,
        "language":"hindi"
    }
)
# Out:
# /var/folders/jj/z9jhw1z95m5bwpgdbhgbvct40000gn/T/ipykernel_83884/3627961428.py:1: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   llm_chain = LLMChain(llm=llm, prompt=prompt)
# /var/folders/jj/z9jhw1z95m5bwpgdbhgbvct40000gn/T/ipykernel_83884/3627961428.py:2: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   summary = llm_chain.run(

# %%
summary
# Out:
# 'Here is the summary of the text in Hindi:\n\nदीप न्यूरल नेटवर्क (DNNs)強력 मॉडल हैं जिन्होंने कठिन सीखने के कार्यों पर शानदार प्रदर्शन किया है। लेकिन DNNs को सीक्वेंस को सीक्वेंस में मैपिंग करने के लिए नहीं किया जा सकता है, जब तक बड़े लेबल्ड ट्रेनिंग सेट उपलब्ध नहीं हैं। इस पेपर में हम एक सामान्य अंत-एंड-एंड सीक्वेंस लर्निंग कि दिशा प्रस्तुत करते हैं, जो सीक्वेंस संरचना के बारे में कुछ भी नहीं मानता है। हमारा मETHOD एक मल्टीलेयर्ड लॉन्ग शार्ट-टर्म मेमोरी (LSTM) है जो प्रवेश सीक्वेंस को एक निर्धारित आयाम के वेक्टर में मैप करता है, और फिर दूसरा गहरा LSTM है जो वेक्टर से लक्ष्य सीक्वेंस को डीकोड करता है। हमारा मुख्य नतजा है कि एक इंग्लिश से फ्रेंच अनुवाद कार्य में LSTM की नतजा एक BLEU स्कोर 34.8 है, जहां LSTM का BLEU स्कोर शब्दावली के बाहर के शब्दों पर पेनल्टी किया गया था। इसके अलावा, LSTM ने लंबे वाक्यों पर कठिनाई नहीं की। इसके लिए एक फेज-आधारित SMT सिस्टम की नतजा एक BLEU स्कोर 33.3 है, जो समान डेटासेट पर है। जब हमने LSTM को aforementioned SMT सिस्टम के 1000 हाइपोटहीज को पुनर्रैंक किया, तो इसका BLEU स्कोर 36.5 हो गया, जो इस कार्य पर पिछले सर्वश्रेष्ठ नतजा के gần है।\n\nइसके अलावा, हमने पाया कि सोर्स सेंटेंस के शब्दों की आदि को उलटने से LSTM की प्रफेशन में काफी सुधार हुआ, क्योंकि ऐसा करने से सोर्स और लक्ष्य सेंटेंस के बीच में संक्षिप्त अवधि के निर्भर लंबे समय की संभावना पैदा हुई, जिससे.optimization की समस्या आसान हो गई।'

# %%
## Stuff Document Chain Text Summarization

from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("/Users/sarthakagarwal/Dropbox/study material/python/genAI/Udemy GenAI/basic_ann_to_gen_ai/langchain-projects/temp.pdf")
pages = loader.load_and_split()
# Out:
# invalid pdf header: b'Conte'
# incorrect startxref pointer(1)
# parsing for Object Streams

# %%
prompt_template = """
Write a concise and short summary with in 200 words of the following text:
Text: {text},
"""

# %%
template = PromptTemplate(
    template=prompt_template,
    input_variables=["text"]
)

# %%
from langchain.chains.summarize import load_summarize_chain

# %%
chain = load_summarize_chain(
    llm=llm,
    chain_type="stuff",
    verbose=True,
    prompt=template
)

# %%
summary = chain.run(
    pages
)
# Out:
# > Entering new StuffDocumentsChain chain...
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
#
# Write a concise and short summary with in 200 words of the following text:
# Text: Star Health And Allied Insurance Company Limited
# To, IMPORTANT
# ADHAR GUPTA    ,
# S/O Devendra kumar agarwal Hno.9 Achar jaan
# Bijnor
# Bijnor Tehsil,Uttar Pradesh-246701
# Mobile : 9719213675
# Date : 05-May-2024
# Dear Customer,
# Re:  Health Insurance Policy - 11240279223503
# We are extremely thankful to you for your renewal instructions and payment of premium. We enclose the
# renewed policy based on our records. We would request you to kindly study the renewed policy carefully and
# revert to us if there is any discrepancy to enable us to attend to the same.
# Kindly note that the above request is very important and if we do not hear anything from you within
# 15 days, we would presume that the policy issued by us is in order and the contract is concluded.
# We would like to mention that we have incorporated the name of the intermediary as indicated by you.
# We wish you good health and we look forward to serve you in the days to come.
# With kind regards,
# Authorised Signatory
#
# In case of a need for hospitalization, kindly prefer our network hospital (list is available in our website) for a
# quick response to your claim request.
# Sum Insured of this Policy is meant for utilization till its expiry.Bearing this aspect in mind,we have no
# doubt,you will choose appropriate hospital,room rent and treatment charges etc.
# However,the ultimate decision will be that of yours only.
# Please select the room as per your eligibility stipulated in your policy to avoid  additional payment
# from your pocket towards the proportionate increase which would invariably be charged by the
# hospital for the higher room category occupied.
# Should you need any assistance, our customer care will be delighted to assist you ,whose toll free no. is
# 1800-425-2255/1800-102-4477.
# Page 1 of 6
# Regd.&Corporate Office:1,New Tank Street,Valluvar Kottam High Road,Nungambakkam,Chennai - 600034,Phone : 044 -28302700 / 28288800
# Toll Free No:1800-425-2255 / 1800-102-4477,CIN : L66010TN2005PLC056649 Email :support@starhealth.in  Website :www.starhealth.in
# IRDAI Regn.no: 129
# This is an electronically generated document(Policy
# Schedule).
#
# Star Health And Allied Insurance Company Limited
# Star Super Surplus (Floater) Insurance Policy
# Unique Identification No. SHAHLIP22034V062122
# Renewal Endorsement No:11240279223503
# Customer Code : GSTIN : 09AAJCS4517L1ZW21775106
# Proposer Code : 21775106 Issuing Office Code : 231119
# Issuing Office Name : Branch Office - MoradabadProposer Name : ADHAR GUPTA
# Shop No. 2 & 3, 2nd Floor,
# Mittal Complex, Above ICICI
# Bank,
# Delhi Road, Moradabad
# Moradabad Tehsil Uttar
# Pradesh 244001
# :Issuing Office AddressS/O Devendra kumar agarwal
# Hno.9 Achar jaan
# Bijnor
# Bijnor Tehsil Uttar Pradesh 246701
# Proposer Address:
# 0591-2487007Phone No :9719213675Phone No :
# : moradabad@starhealth.inE-mail Idaamodkumar69@yahoo.inE-mail Id :
# NO:Proposer GSTIN
# : 08-May-2021Proposal date Fulfiller Code : SH24290
# Place of Supply Uttar Pradesh:
# In Consideration of payment of Rs. 11,894/- towards renewal premium of policy
# number:11240279223502, the policy stands renewed for a further period of 1 Year as per the details
# given below
# SAC Code : 997133 / Accident and Health
# Insurance Services
# Customer Name : ADHAR GUPTA
# Cust CKYC No : 60036496137188
# BA0000169109Intermediary
# Code
# :Third Year:Renewal Year
# Collection No 231119/RV/2025/0125330024:
# 05-May-2024Collection Date :
# Date of Inception
# of first policy
# 08-May-2021:
# : AAMOD KUMARName: 10,080/-Premium Rs.
# :Phone No 9412855891CGST @ 9% : Rs. 907/-
# :aamodkumar69@yaho
# o.in
# E-mail Id: Rs. 907/-SGST @ 9%
# Re. 1/-Stamp Duty :
# Total Premium : Rs. 11,894/-
# Total Premium In Words : Rupees Eleven thousand eight hundred ninety four
# only
# PERIOD OF INSURANCE : From : 08-May-2024   00:00 :To Midnight Of 07-May-2025 Policy Term :1 Year
# Installment Facility Option:No Premium Payment Frequency :Annual Installment Amount Rs. : 0/-
# Sum Insured  : Rs. 25,00,000 Defined Limit (Rs.)  : 5,00,000
# Sum Insured in words  : Indian Rupees Twenty Five lakhs  only
# Plan Type  : Family Size  : 2A+2CGOLD
# Entered by
# :  PORTAL
# For Star Health and Allied Insurance Company Ltd.
# Approved by
# :  CUSTPORTAL
# Authorised Signatory
#
# Page 2 of 6
# Email ID: info@starhealth.in
# IRDAI Regn.No.129
# Corporate Identity Number L66010TN2005PLC056649
# Regd.&Corporate Office:1,New Tank Street,Valluvar Kottam High Road,Nungambakkam,Chennai - 600034,Phone : 044 -28302700 / 28288800
# Toll Free No:1800-425-2255 / 1800-102-4477,CIN : L66010TN2005PLC056649 Email :support@starhealth.in  Website :www.starhealth.in
# IRDAI Regn.no: 129
# This is an electronically generated document(Policy
# Schedule).
#
# Star Health And Allied Insurance Company Limited
# Attached to and forming part of Policy No:  11240279223503
# Details of Insured Persons :
# ID Card NoAge in
# YrsDate of Birth Inception
# date
# Sl.
# no. Name of the Insured Relationship
# with ProposerGender
# 1 ADHAR GUPTA Male 26-Nov-1976 47 Self 21775106-1 08-May-2021
# No PED DeclaredPre Existing Disease :
# 2 SHALINI GUPTA Female 06-Aug-1979 44 Spouse 21775106-2 08-May-2021
# No PED DeclaredPre Existing Disease :
# 3 DIVIK GUPTA Male 05-Aug-2004 19 Son 21775106-3 08-May-2021
# No PED DeclaredPre Existing Disease :
# 4 MADHAV GUPTA Male 12-May-2008 15 Son 21775106-4 08-May-2021
# No PED DeclaredPre Existing Disease :
# Nominee Details:
# S.No Name Relationship
# with proposer
# Age % of the
# claim
# Appointee Name Appointee
# Age
# Relationship
# with nominee
# 1 SHALINI GUPTA Spouse 44 100
# Nominee Details for the Proposer Appointee Details
# Urban
# Sector Classification:
# Please check whether the details given by you about the Insured persons in the Proposal Form are incorporated
# correctly in the Policy.If you find any discrepancy , please inform us within 15 days from the date of receipt of the
# policy, failing which the details relating to the Insured persons given  in the Policy are deemed to have been
# accepted by you.
# Warranted that in case of dishonour of premium cheque(s) the Company shall not be liable under the policy and
# the policy shall be void abinitio.
# Important
# In the event of hospitalization of insured person, intimation should be given to the Company immediately,
# however, within 24 hrs from the time of admission.
# Toll Free No:1800 425 2255/1800 102 4477 Email: support@starhealth.in, Fax No: 1800 425 5522.
# It is hereby made clear that all terms, conditions, clauses, warranties, exclusions etc., as already issued, forming
# part of the policy of insurance originally issued at the time of inception of this relationship, shall continue to be
# operative and unaltered, forming part of this renewal insurance cover also.
# Reference may be made to those terms, conditions etc., for identifying the scope/extent of coverage.
# Other excluded expenses as detailed in our website www.starhealth.in
# In witness whereof the undersigned being authorized here in to set his hand at Branch Office - Moradabad on 05th
# Day of  May 2024.
# Entered by
# :  PORTAL
# For Star Health and Allied Insurance Company Ltd.
# Approved by
# :  CUSTPORTAL
# Authorised Signatory
#
# Page 3 of 6
# Regd.&Corporate Office:1,New Tank Street,Valluvar Kottam High Road,Nungambakkam,Chennai - 600034,Phone : 044 -28302700 / 28288800
# Toll Free No:1800-425-2255 / 1800-102-4477,CIN : L66010TN2005PLC056649 Email :support@starhealth.in  Website :www.starhealth.in
# IRDAI Regn.no: 129
# This is an electronically generated document(Policy
# Schedule).
#
# Star Health And Allied Insurance Company Limited
# As per Section 34 of CGST Act of 2017, Policy Issued in one Financial Year and Cancelled in another Financial Year
# on or after 01st of December, then Only Premium Amount will be Refunded to the Customer and GST Amount will
# Not be Refunded. Customer has to Claim the Refund of GST Amount from the GST Portal.
# Entered by
# :  PORTAL
# For Star Health and Allied Insurance Company Ltd.
# Approved by
# :  CUSTPORTAL
# Authorised Signatory
#
# Page 4 of 6
# Regd.&Corporate Office:1,New Tank Street,Valluvar Kottam High Road,Nungambakkam,Chennai - 600034,Phone : 044 -28302700 / 28288800
# Toll Free No:1800-425-2255 / 1800-102-4477,CIN : L66010TN2005PLC056649 Email :support@starhealth.in  Website :www.starhealth.in
# IRDAI Regn.no: 129
# This is an electronically generated document(Policy
# Schedule).
#
# Star Health And Allied Insurance Company Limited
# 231119-Branch Office - MoradabadIssue Office :
# Shop No. 2 & 3, 2nd Floor,
# Mittal Complex, Above ICICI Bank,
# Delhi Road, Moradabad
# Moradabad Tehsil Uttar Pradesh 244001
# Address :
# 0591-2487007Tel / Fax :
# moradabad@starhealth.inEmail :
# This is to certify that ADHAR GUPTA     has paid Rs 11,894/- (Total Premium : Indian Rupees Eleven thousand
# eight hundred ninety four only ) towards Premium for Hospitalization Insurance vide Policy No:
# 11240279223503 for the Period 08-May-2024 To 07-May-2025 issued on 05-May-2024.
# Payment received by Payment Gateway vide Receipt No: 231119/RV/2025/0125330024/1 Receipt
# Date: 05-May-2024
# This Certificate must be surrendered to the Insurance Company for issuance of fresh Certificate in
# case of Cancellation of the Policy or any alteration in the Insurance affecting the Premium.
# Note :-
# Hospitalisation Benefit Policy
# Premium Certificate for the purpose of deduction under Section 80 D of Income Tax (Amendment) Act,1986
# Authorised Signatory
# For and on behalf of
# Place : Branch Office - Moradabad
# Date : 05-May-2024
#
# Star Health and Allied Insurance Company Ltd.
# IRDA Regn.No.129
# Email ID: info@starhealth.in
# Corporate Identity Number L66010TN2005PLC056649
# Policy No : Type of Policy  :11240279223503 Super Surplus Floater Revised-
# 2021
# Entered by
# :  PORTAL
# For Star Health and Allied Insurance Company Ltd.
# Approved by
# :  CUSTPORTAL
# Authorised Signatory
#
# Page 5 of 6
# Regd.&Corporate Office:1,New Tank Street,Valluvar Kottam High Road,Nungambakkam,Chennai - 600034,Phone : 044 -28302700 / 28288800
# Toll Free No:1800-425-2255 / 1800-102-4477,CIN : L66010TN2005PLC056649 Email :support@starhealth.in  Website :www.starhealth.in
# IRDAI Regn.no: 129
# This is an electronically generated document(Policy
# Schedule).
#
# Star Health And Allied Insurance Company Limited
# Tax Invoice
# Recipient Supplier
# GSTIN GSTIN 09AAJCS4517L1ZW::
# Name ADHAR GUPTA Name Star Health and Allied Insurance Co Ltd -
# Branch Office - Moradabad
# ::
# Address S/O Devendra kumar agarwal Hno.9
# Achar jaan
# Address Shop No. 2 & 3, 2nd Floor,::
# Bijnor Mittal Complex, Above ICICI Bank,
#  Delhi Road, Moradabad
# : Bijnor TehsilCity Pin Code  :  246701 : Moradabad
# Tehsil
# City Pin Code 244001:
# : Uttar PradeshState Place of
# supply
# Uttar Pradesh:: Uttar Pradesh State Client
# Category
#  IND:
# Invoice No. 092405I003493898 Customer ID 21775106::
# Invoice Date 05-May-2024 Policy No. 11240279223503::
# This is a digitally signed document and hence no physical signature is required
# IRDAI Regn.No.129 Email ID: stargst@starhealth.inCorporate Identity Number L66010TN2005PLC056649
# Important Note:
# The invoice is issued as per Section 31 of the CGST Act
# In case no GSTIN or incorrect GSTIN is provided by the Proposer at Proposal stage, Star Health and Allied Insurance Co Ltd shall not be
# responsible for any Input Tax Credit losses and no subsequent revision of invoice will be undertaken
# "I/We hereby declare that though our aggregate turnover in any preceding financial year from 2017-18 onwards is more than the aggregate
# turnover notified under sub-rule (4) of rule 48, we are not required to prepare an invoice in terms of the provisions of the said sub-rule."
# E. & O.E
#
# Total Invoice Value (in Figures) Rs. 11,894/-:
# Total Invoice Value (in Words) Rupees Eleven thousand eight hundred ninety four only:
# Amount of Tax Subject to reverse Charge No:
# B C = A - B D = C *
# IGST
# E = C *
# CGST
# F = C *
# UTGST or
# SGST
# Discount Taxable
# Value
# IGST @
# 18% CGST @ 9% UT/SGST @
# 9%
# H = C + D +
# E+ F + G
# Description of
# Service(s)
# HSN / SAC
# Code
# Total
# A
# Total Invoice
# Value
# CESS @
# 1%
# G= C *
# Cess
# 997133 Insurance
# Services 10,080.00 0 10,080.00 0 907.00 907.00 11,894.000
# Entered by
# :  PORTAL
# For Star Health and Allied Insurance Company Ltd.
# Approved by
# :  CUSTPORTAL
# Authorised Signatory
#
# Page 6 of 6
# Regd.&Corporate Office:1,New Tank Street,Valluvar Kottam High Road,Nungambakkam,Chennai - 600034,Phone : 044 -28302700 / 28288800
# Toll Free No:1800-425-2255 / 1800-102-4477,CIN : L66010TN2005PLC056649 Email :support@starhealth.in  Website :www.starhealth.in
# IRDAI Regn.no: 129
# This is an electronically generated document(Policy
# Schedule).,
#
#
# > Finished chain.
#
# > Finished chain.

# %%
print(summary)
# Out:
# Here is a concise and short summary of the text within 200 words:
#
# Star Health and Allied Insurance Company Limited has issued a renewal policy to Adhar Gupta, with policy number 11240279223503. The policy is a Star Super Surplus (Floater) Insurance Policy with a sum insured of Rs. 25,00,000 and a premium of Rs. 11,894. The policy covers Adhar Gupta, his spouse Shalini Gupta, and their two sons, Divik Gupta and Madhav Gupta. The policy period is from May 8, 2024, to May 7, 2025. The policy includes a hospitalization benefit and covers pre-existing diseases. The policyholder is required to inform the insurance company immediately in case of hospitalization and to provide a copy of the hospital bill. The policy also includes a tax invoice with details of the premium paid. The insurance company has requested the policyholder to review the policy carefully and revert with any discrepancies.

# %%
# Map Reduce Summarization Chain

from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200
).split_documents(pages)

# %%
text_splitter
# Out:
# [Document(metadata={'producer': 'iText 2.1.6 by 1T3XT; modified using iText® 5.3.2 ©2000-2012 1T3XT BVBA (AGPL-version)', 'creator': 'JasperReports Library version 5.6.0', 'creationdate': '2024-05-05T12:26:01+05:30', 'moddate': '2024-05-05T12:25:58+05:30', 'source': '/Users/sarthakagarwal/Dropbox/study material/python/genAI/Udemy GenAI/basic_ann_to_gen_ai/langchain-projects/temp.pdf', 'total_pages': 6, 'page': 0, 'page_label': '1'}, page_content='Star Health And Allied Insurance Company Limited\nTo, IMPORTANT\nADHAR GUPTA    ,\nS/O Devendra kumar agarwal Hno.9 Achar jaan\nBijnor\nBijnor Tehsil,Uttar Pradesh-246701\nMobile : 9719213675\nDate : 05-May-2024\nDear Customer,\nRe:  Health Insurance Policy - 11240279223503\nWe are extremely thankful to you for your renewal instructions and payment of premium. We enclose the\nrenewed policy based on our records. We would request you to kindly study the renewed policy carefully and\nrevert to us if there is any discrepancy to enable us to attend to the same.\nKindly note that the above request is very important and if we do not hear anything from you within\n15 days, we would presume that the policy issued by us is in order and the contract is concluded.\nWe would like to mention that we have incorporated the name of the intermediary as indicated by you.\nWe wish you good health and we look forward to serve you in the days to come.\nWith kind regards,\nAuthorised Signatory'),
#  Document(metadata={'producer': 'iText 2.1.6 by 1T3XT; modified using iText® 5.3.2 ©2000-2012 1T3XT BVBA (AGPL-version)', 'creator': 'JasperReports Library version 5.6.0', 'creationdate': '2024-05-05T12:26:01+05:30', 'moddate': '2024-05-05T12:25:58+05:30', 'source': '/Users/sarthakagarwal/Dropbox/study material/python/genAI/Udemy GenAI/basic_ann_to_gen_ai/langchain-projects/temp.pdf', 'total_pages': 6, 'page': 0, 'page_label': '1'}, page_content='We wish you good health and we look forward to serve you in the days to come.\nWith kind regards,\nAuthorised Signatory\n \nIn case of a need for hospitalization, kindly prefer our network hospital (list is available in our website) for a\nquick response to your claim request.\nSum Insured of this Policy is meant for utilization till its expiry.Bearing this aspect in mind,we have no\ndoubt,you will choose appropriate hospital,room rent and treatment charges etc.\nHowever,the ultimate decision will be that of yours only.\nPlease select the room as per your eligibility stipulated in your policy to avoid  additional payment\nfrom your pocket towards the proportionate increase which would invariably be charged by the\nhospital for the higher room category occupied.\nShould you need any assistance, our customer care will be delighted to assist you ,whose toll free no. is\n1800-425-2255/1800-102-4477.\nPage 1 of 6'),
#  Document(metadata={'producer': 'iText 2.1.6 by 1T3XT; modified using iText® 5.3.2 ©2000-2012 1T3XT BVBA (AGPL-version)', 'creator': 'JasperReports Library version 5.6.0', 'creationdate': '2024-05-05T12:26:01+05:30', 'moddate': '2024-05-05T12:25:58+05:30', 'source': '/Users/sarthakagarwal/Dropbox/study material/python/genAI/Udemy GenAI/basic_ann_to_gen_ai/langchain-projects/temp.pdf', 'total_pages': 6, 'page': 0, 'page_label': '1'}, page_content='hospital for the higher room category occupied.\nShould you need any assistance, our customer care will be delighted to assist you ,whose toll free no. is\n1800-425-2255/1800-102-4477.\nPage 1 of 6\nRegd.&Corporate Office:1,New Tank Street,Valluvar Kottam High Road,Nungambakkam,Chennai - 600034,Phone : 044 -28302700 / 28288800\nToll Free No:1800-425-2255 / 1800-102-4477,CIN : L66010TN2005PLC056649 Email :support@starhealth.in  Website :www.starhealth.in\nIRDAI Regn.no: 129\nThis is an electronically generated document(Policy\nSchedule).'),
#  Document(metadata={'producer': 'iText 2.1.6 by 1T3XT; modified using iText® 5.3.2 ©2000-2012 1T3XT BVBA (AGPL-version)', 'creator': 'JasperReports Library version 5.6.0', 'creationdate': '2024-05-05T12:26:01+05:30', 'moddate': '2024-05-05T12:25:58+05:30', 'source': '/Users/sarthakagarwal/Dropbox/study material/python/genAI/Udemy GenAI/basic_ann_to_gen_ai/langchain-projects/temp.pdf', 'total_pages': 6, 'page': 1, 'page_label': '2'}, page_content='Star Health And Allied Insurance Company Limited\nStar Super Surplus (Floater) Insurance Policy\nUnique Identification No. SHAHLIP22034V062122\nRenewal Endorsement No:11240279223503\nCustomer Code : GSTIN : 09AAJCS4517L1ZW21775106\nProposer Code : 21775106 Issuing Office Code : 231119\nIssuing Office Name : Branch Office - MoradabadProposer Name : ADHAR GUPTA\nShop No. 2 & 3, 2nd Floor,\nMittal Complex, Above ICICI\nBank,\nDelhi Road, Moradabad\nMoradabad Tehsil Uttar\nPradesh 244001\n:Issuing Office AddressS/O Devendra kumar agarwal\nHno.9 Achar jaan\nBijnor\nBijnor Tehsil Uttar Pradesh 246701\nProposer Address:\n0591-2487007Phone No :9719213675Phone No :\n: moradabad@starhealth.inE-mail Idaamodkumar69@yahoo.inE-mail Id :\nNO:Proposer GSTIN\n: 08-May-2021Proposal date Fulfiller Code : SH24290\nPlace of Supply Uttar Pradesh:\nIn Consideration of payment of Rs. 11,894/- towards renewal premium of policy\nnumber:11240279223502, the policy stands renewed for a further period of 1 Year as per the details'),
#  Document(metadata={'producer': 'iText 2.1.6 by 1T3XT; modified using iText® 5.3.2 ©2000-2012 1T3XT BVBA (AGPL-version)', 'creator': 'JasperReports Library version 5.6.0', 'creationdate': '2024-05-05T12:26:01+05:30', 'moddate': '2024-05-05T12:25:58+05:30', 'source': '/Users/sarthakagarwal/Dropbox/study material/python/genAI/Udemy GenAI/basic_ann_to_gen_ai/langchain-projects/temp.pdf', 'total_pages': 6, 'page': 1, 'page_label': '2'}, page_content='In Consideration of payment of Rs. 11,894/- towards renewal premium of policy\nnumber:11240279223502, the policy stands renewed for a further period of 1 Year as per the details\ngiven below\nSAC Code : 997133 / Accident and Health\nInsurance Services\nCustomer Name : ADHAR GUPTA\nCust CKYC No : 60036496137188\nBA0000169109Intermediary\nCode\n:Third Year:Renewal Year\nCollection No 231119/RV/2025/0125330024:\n05-May-2024Collection Date :\nDate of Inception\nof first policy\n08-May-2021:\n: AAMOD KUMARName: 10,080/-Premium Rs.\n:Phone No 9412855891CGST @ 9% : Rs. 907/-\n:aamodkumar69@yaho\no.in\nE-mail Id: Rs. 907/-SGST @ 9%\nRe. 1/-Stamp Duty :\nTotal Premium : Rs. 11,894/-\nTotal Premium In Words : Rupees Eleven thousand eight hundred ninety four\nonly\nPERIOD OF INSURANCE : From : 08-May-2024   00:00 :To Midnight Of 07-May-2025 Policy Term :1 Year\nInstallment Facility Option:No Premium Payment Frequency :Annual Installment Amount Rs. : 0/-\nSum Insured  : Rs. 25,00,000 Defined Limit (Rs.)  : 5,00,000'),
#  Document(metadata={'producer': 'iText 2.1.6 by 1T3XT; modified using iText® 5.3.2 ©2000-2012 1T3XT BVBA (AGPL-version)', 'creator': 'JasperReports Library version 5.6.0', 'creationdate': '2024-05-05T12:26:01+05:30', 'moddate': '2024-05-05T12:25:58+05:30', 'source': '/Users/sarthakagarwal/Dropbox/study material/python/genAI/Udemy GenAI/basic_ann_to_gen_ai/langchain-projects/temp.pdf', 'total_pages': 6, 'page': 1, 'page_label': '2'}, page_content='Installment Facility Option:No Premium Payment Frequency :Annual Installment Amount Rs. : 0/-\nSum Insured  : Rs. 25,00,000 Defined Limit (Rs.)  : 5,00,000\nSum Insured in words  : Indian Rupees Twenty Five lakhs  only\nPlan Type  : Family Size  : 2A+2CGOLD\nEntered by\n:  PORTAL\nFor Star Health and Allied Insurance Company Ltd.\nApproved by\n:  CUSTPORTAL\nAuthorised Signatory\n \nPage 2 of 6\nEmail ID: info@starhealth.in\nIRDAI Regn.No.129\nCorporate Identity Number L66010TN2005PLC056649\nRegd.&Corporate Office:1,New Tank Street,Valluvar Kottam High Road,Nungambakkam,Chennai - 600034,Phone : 044 -28302700 / 28288800\nToll Free No:1800-425-2255 / 1800-102-4477,CIN : L66010TN2005PLC056649 Email :support@starhealth.in  Website :www.starhealth.in\nIRDAI Regn.no: 129\nThis is an electronically generated document(Policy\nSchedule).'),
#  Document(metadata={'producer': 'iText 2.1.6 by 1T3XT; modified using iText® 5.3.2 ©2000-2012 1T3XT BVBA (AGPL-version)', 'creator': 'JasperReports Library version 5.6.0', 'creationdate': '2024-05-05T12:26:01+05:30', 'moddate': '2024-05-05T12:25:58+05:30', 'source': '/Users/sarthakagarwal/Dropbox/study material/python/genAI/Udemy GenAI/basic_ann_to_gen_ai/langchain-projects/temp.pdf', 'total_pages': 6, 'page': 2, 'page_label': '3'}, page_content='Star Health And Allied Insurance Company Limited\nAttached to and forming part of Policy No:  11240279223503\nDetails of Insured Persons :\nID Card NoAge in\nYrsDate of Birth Inception\ndate\nSl.\nno. Name of the Insured Relationship\nwith ProposerGender\n1 ADHAR GUPTA Male 26-Nov-1976 47 Self 21775106-1 08-May-2021\nNo PED DeclaredPre Existing Disease :\n2 SHALINI GUPTA Female 06-Aug-1979 44 Spouse 21775106-2 08-May-2021\nNo PED DeclaredPre Existing Disease :\n3 DIVIK GUPTA Male 05-Aug-2004 19 Son 21775106-3 08-May-2021\nNo PED DeclaredPre Existing Disease :\n4 MADHAV GUPTA Male 12-May-2008 15 Son 21775106-4 08-May-2021\nNo PED DeclaredPre Existing Disease :\nNominee Details:\nS.No Name Relationship\nwith proposer\nAge % of the\nclaim\nAppointee Name Appointee\nAge\nRelationship\nwith nominee\n1 SHALINI GUPTA Spouse 44 100 \nNominee Details for the Proposer Appointee Details\nUrban \nSector Classification:'),
#  Document(metadata={'producer': 'iText 2.1.6 by 1T3XT; modified using iText® 5.3.2 ©2000-2012 1T3XT BVBA (AGPL-version)', 'creator': 'JasperReports Library version 5.6.0', 'creationdate': '2024-05-05T12:26:01+05:30', 'moddate': '2024-05-05T12:25:58+05:30', 'source': '/Users/sarthakagarwal/Dropbox/study material/python/genAI/Udemy GenAI/basic_ann_to_gen_ai/langchain-projects/temp.pdf', 'total_pages': 6, 'page': 2, 'page_label': '3'}, page_content='with proposer\nAge % of the\nclaim\nAppointee Name Appointee\nAge\nRelationship\nwith nominee\n1 SHALINI GUPTA Spouse 44 100 \nNominee Details for the Proposer Appointee Details\nUrban \nSector Classification:\nPlease check whether the details given by you about the Insured persons in the Proposal Form are incorporated\ncorrectly in the Policy.If you find any discrepancy , please inform us within 15 days from the date of receipt of the\npolicy, failing which the details relating to the Insured persons given  in the Policy are deemed to have been\naccepted by you.\nWarranted that in case of dishonour of premium cheque(s) the Company shall not be liable under the policy and\nthe policy shall be void abinitio.\nImportant\nIn the event of hospitalization of insured person, intimation should be given to the Company immediately,\nhowever, within 24 hrs from the time of admission.\nToll Free No:1800 425 2255/1800 102 4477 Email: support@starhealth.in, Fax No: 1800 425 5522.'),
#  Document(metadata={'producer': 'iText 2.1.6 by 1T3XT; modified using iText® 5.3.2 ©2000-2012 1T3XT BVBA (AGPL-version)', 'creator': 'JasperReports Library version 5.6.0', 'creationdate': '2024-05-05T12:26:01+05:30', 'moddate': '2024-05-05T12:25:58+05:30', 'source': '/Users/sarthakagarwal/Dropbox/study material/python/genAI/Udemy GenAI/basic_ann_to_gen_ai/langchain-projects/temp.pdf', 'total_pages': 6, 'page': 2, 'page_label': '3'}, page_content='however, within 24 hrs from the time of admission.\nToll Free No:1800 425 2255/1800 102 4477 Email: support@starhealth.in, Fax No: 1800 425 5522.\nIt is hereby made clear that all terms, conditions, clauses, warranties, exclusions etc., as already issued, forming\npart of the policy of insurance originally issued at the time of inception of this relationship, shall continue to be\noperative and unaltered, forming part of this renewal insurance cover also.\nReference may be made to those terms, conditions etc., for identifying the scope/extent of coverage.\nOther excluded expenses as detailed in our website www.starhealth.in\nIn witness whereof the undersigned being authorized here in to set his hand at Branch Office - Moradabad on 05th\nDay of  May 2024.\nEntered by\n:  PORTAL\nFor Star Health and Allied Insurance Company Ltd.\nApproved by\n:  CUSTPORTAL\nAuthorised Signatory\n \nPage 3 of 6'),
#  Document(metadata={'producer': 'iText 2.1.6 by 1T3XT; modified using iText® 5.3.2 ©2000-2012 1T3XT BVBA (AGPL-version)', 'creator': 'JasperReports Library version 5.6.0', 'creationdate': '2024-05-05T12:26:01+05:30', 'moddate': '2024-05-05T12:25:58+05:30', 'source': '/Users/sarthakagarwal/Dropbox/study material/python/genAI/Udemy GenAI/basic_ann_to_gen_ai/langchain-projects/temp.pdf', 'total_pages': 6, 'page': 2, 'page_label': '3'}, page_content='Day of  May 2024.\nEntered by\n:  PORTAL\nFor Star Health and Allied Insurance Company Ltd.\nApproved by\n:  CUSTPORTAL\nAuthorised Signatory\n \nPage 3 of 6\nRegd.&Corporate Office:1,New Tank Street,Valluvar Kottam High Road,Nungambakkam,Chennai - 600034,Phone : 044 -28302700 / 28288800\nToll Free No:1800-425-2255 / 1800-102-4477,CIN : L66010TN2005PLC056649 Email :support@starhealth.in  Website :www.starhealth.in\nIRDAI Regn.no: 129\nThis is an electronically generated document(Policy\nSchedule).'),
#  Document(metadata={'producer': 'iText 2.1.6 by 1T3XT; modified using iText® 5.3.2 ©2000-2012 1T3XT BVBA (AGPL-version)', 'creator': 'JasperReports Library version 5.6.0', 'creationdate': '2024-05-05T12:26:01+05:30', 'moddate': '2024-05-05T12:25:58+05:30', 'source': '/Users/sarthakagarwal/Dropbox/study material/python/genAI/Udemy GenAI/basic_ann_to_gen_ai/langchain-projects/temp.pdf', 'total_pages': 6, 'page': 3, 'page_label': '4'}, page_content='Star Health And Allied Insurance Company Limited\nAs per Section 34 of CGST Act of 2017, Policy Issued in one Financial Year and Cancelled in another Financial Year\non or after 01st of December, then Only Premium Amount will be Refunded to the Customer and GST Amount will\nNot be Refunded. Customer has to Claim the Refund of GST Amount from the GST Portal.\nEntered by\n:  PORTAL\nFor Star Health and Allied Insurance Company Ltd.\nApproved by\n:  CUSTPORTAL\nAuthorised Signatory\n \nPage 4 of 6\nRegd.&Corporate Office:1,New Tank Street,Valluvar Kottam High Road,Nungambakkam,Chennai - 600034,Phone : 044 -28302700 / 28288800\nToll Free No:1800-425-2255 / 1800-102-4477,CIN : L66010TN2005PLC056649 Email :support@starhealth.in  Website :www.starhealth.in\nIRDAI Regn.no: 129\nThis is an electronically generated document(Policy\nSchedule).'),
#  Document(metadata={'producer': 'iText 2.1.6 by 1T3XT; modified using iText® 5.3.2 ©2000-2012 1T3XT BVBA (AGPL-version)', 'creator': 'JasperReports Library version 5.6.0', 'creationdate': '2024-05-05T12:26:01+05:30', 'moddate': '2024-05-05T12:25:58+05:30', 'source': '/Users/sarthakagarwal/Dropbox/study material/python/genAI/Udemy GenAI/basic_ann_to_gen_ai/langchain-projects/temp.pdf', 'total_pages': 6, 'page': 4, 'page_label': '5'}, page_content='Star Health And Allied Insurance Company Limited\n231119-Branch Office - MoradabadIssue Office :\nShop No. 2 & 3, 2nd Floor,\nMittal Complex, Above ICICI Bank,\nDelhi Road, Moradabad\nMoradabad Tehsil Uttar Pradesh 244001\nAddress :\n0591-2487007Tel / Fax :\nmoradabad@starhealth.inEmail :\nThis is to certify that ADHAR GUPTA     has paid Rs 11,894/- (Total Premium : Indian Rupees Eleven thousand\neight hundred ninety four only ) towards Premium for Hospitalization Insurance vide Policy No:\n11240279223503 for the Period 08-May-2024 To 07-May-2025 issued on 05-May-2024.\nPayment received by Payment Gateway vide Receipt No: 231119/RV/2025/0125330024/1 Receipt\nDate: 05-May-2024\nThis Certificate must be surrendered to the Insurance Company for issuance of fresh Certificate in\ncase of Cancellation of the Policy or any alteration in the Insurance affecting the Premium.\nNote :-\nHospitalisation Benefit Policy'),
#  Document(metadata={'producer': 'iText 2.1.6 by 1T3XT; modified using iText® 5.3.2 ©2000-2012 1T3XT BVBA (AGPL-version)', 'creator': 'JasperReports Library version 5.6.0', 'creationdate': '2024-05-05T12:26:01+05:30', 'moddate': '2024-05-05T12:25:58+05:30', 'source': '/Users/sarthakagarwal/Dropbox/study material/python/genAI/Udemy GenAI/basic_ann_to_gen_ai/langchain-projects/temp.pdf', 'total_pages': 6, 'page': 4, 'page_label': '5'}, page_content='case of Cancellation of the Policy or any alteration in the Insurance affecting the Premium.\nNote :-\nHospitalisation Benefit Policy\nPremium Certificate for the purpose of deduction under Section 80 D of Income Tax (Amendment) Act,1986\nAuthorised Signatory\nFor and on behalf of\nPlace : Branch Office - Moradabad\nDate : 05-May-2024\n \nStar Health and Allied Insurance Company Ltd.\nIRDA Regn.No.129\nEmail ID: info@starhealth.in\nCorporate Identity Number L66010TN2005PLC056649\nPolicy No : Type of Policy  :11240279223503 Super Surplus Floater Revised-\n2021\nEntered by\n:  PORTAL\nFor Star Health and Allied Insurance Company Ltd.\nApproved by\n:  CUSTPORTAL\nAuthorised Signatory\n \nPage 5 of 6\nRegd.&Corporate Office:1,New Tank Street,Valluvar Kottam High Road,Nungambakkam,Chennai - 600034,Phone : 044 -28302700 / 28288800\nToll Free No:1800-425-2255 / 1800-102-4477,CIN : L66010TN2005PLC056649 Email :support@starhealth.in  Website :www.starhealth.in\nIRDAI Regn.no: 129'),
#  Document(metadata={'producer': 'iText 2.1.6 by 1T3XT; modified using iText® 5.3.2 ©2000-2012 1T3XT BVBA (AGPL-version)', 'creator': 'JasperReports Library version 5.6.0', 'creationdate': '2024-05-05T12:26:01+05:30', 'moddate': '2024-05-05T12:25:58+05:30', 'source': '/Users/sarthakagarwal/Dropbox/study material/python/genAI/Udemy GenAI/basic_ann_to_gen_ai/langchain-projects/temp.pdf', 'total_pages': 6, 'page': 4, 'page_label': '5'}, page_content='Toll Free No:1800-425-2255 / 1800-102-4477,CIN : L66010TN2005PLC056649 Email :support@starhealth.in  Website :www.starhealth.in\nIRDAI Regn.no: 129\nThis is an electronically generated document(Policy\nSchedule).'),
#  Document(metadata={'producer': 'iText 2.1.6 by 1T3XT; modified using iText® 5.3.2 ©2000-2012 1T3XT BVBA (AGPL-version)', 'creator': 'JasperReports Library version 5.6.0', 'creationdate': '2024-05-05T12:26:01+05:30', 'moddate': '2024-05-05T12:25:58+05:30', 'source': '/Users/sarthakagarwal/Dropbox/study material/python/genAI/Udemy GenAI/basic_ann_to_gen_ai/langchain-projects/temp.pdf', 'total_pages': 6, 'page': 5, 'page_label': '6'}, page_content='Star Health And Allied Insurance Company Limited\nTax Invoice\nRecipient Supplier\nGSTIN GSTIN 09AAJCS4517L1ZW::\nName ADHAR GUPTA Name Star Health and Allied Insurance Co Ltd -\nBranch Office - Moradabad\n::\nAddress S/O Devendra kumar agarwal Hno.9\nAchar jaan\nAddress Shop No. 2 & 3, 2nd Floor,::\nBijnor Mittal Complex, Above ICICI Bank,\n Delhi Road, Moradabad\n: Bijnor TehsilCity Pin Code  :  246701 : Moradabad\nTehsil\nCity Pin Code 244001:\n: Uttar PradeshState Place of\nsupply\nUttar Pradesh:: Uttar Pradesh State Client\nCategory\n IND:\nInvoice No. 092405I003493898 Customer ID 21775106::\nInvoice Date 05-May-2024 Policy No. 11240279223503::\nThis is a digitally signed document and hence no physical signature is required\nIRDAI Regn.No.129 Email ID: stargst@starhealth.inCorporate Identity Number L66010TN2005PLC056649\nImportant Note:\nThe invoice is issued as per Section 31 of the CGST Act'),
#  Document(metadata={'producer': 'iText 2.1.6 by 1T3XT; modified using iText® 5.3.2 ©2000-2012 1T3XT BVBA (AGPL-version)', 'creator': 'JasperReports Library version 5.6.0', 'creationdate': '2024-05-05T12:26:01+05:30', 'moddate': '2024-05-05T12:25:58+05:30', 'source': '/Users/sarthakagarwal/Dropbox/study material/python/genAI/Udemy GenAI/basic_ann_to_gen_ai/langchain-projects/temp.pdf', 'total_pages': 6, 'page': 5, 'page_label': '6'}, page_content='IRDAI Regn.No.129 Email ID: stargst@starhealth.inCorporate Identity Number L66010TN2005PLC056649\nImportant Note:\nThe invoice is issued as per Section 31 of the CGST Act\nIn case no GSTIN or incorrect GSTIN is provided by the Proposer at Proposal stage, Star Health and Allied Insurance Co Ltd shall not be\nresponsible for any Input Tax Credit losses and no subsequent revision of invoice will be undertaken\n"I/We hereby declare that though our aggregate turnover in any preceding financial year from 2017-18 onwards is more than the aggregate\nturnover notified under sub-rule (4) of rule 48, we are not required to prepare an invoice in terms of the provisions of the said sub-rule."\nE. & O.E\n \nTotal Invoice Value (in Figures) Rs. 11,894/-:\nTotal Invoice Value (in Words) Rupees Eleven thousand eight hundred ninety four only:\nAmount of Tax Subject to reverse Charge No:\nB C = A - B D = C *\nIGST\nE = C *\nCGST\nF = C *\nUTGST or\nSGST\nDiscount Taxable\nValue\nIGST @\n18% CGST @ 9% UT/SGST @\n9%\nH = C + D +'),
#  Document(metadata={'producer': 'iText 2.1.6 by 1T3XT; modified using iText® 5.3.2 ©2000-2012 1T3XT BVBA (AGPL-version)', 'creator': 'JasperReports Library version 5.6.0', 'creationdate': '2024-05-05T12:26:01+05:30', 'moddate': '2024-05-05T12:25:58+05:30', 'source': '/Users/sarthakagarwal/Dropbox/study material/python/genAI/Udemy GenAI/basic_ann_to_gen_ai/langchain-projects/temp.pdf', 'total_pages': 6, 'page': 5, 'page_label': '6'}, page_content='Amount of Tax Subject to reverse Charge No:\nB C = A - B D = C *\nIGST\nE = C *\nCGST\nF = C *\nUTGST or\nSGST\nDiscount Taxable\nValue\nIGST @\n18% CGST @ 9% UT/SGST @\n9%\nH = C + D +\nE+ F + G\nDescription of\nService(s)\nHSN / SAC\nCode\nTotal\nA\nTotal Invoice\nValue\nCESS @\n1%\nG= C *\nCess\n997133 Insurance\nServices 10,080.00 0 10,080.00 0 907.00 907.00 11,894.000\nEntered by\n:  PORTAL\nFor Star Health and Allied Insurance Company Ltd.\nApproved by\n:  CUSTPORTAL\nAuthorised Signatory\n \nPage 6 of 6\nRegd.&Corporate Office:1,New Tank Street,Valluvar Kottam High Road,Nungambakkam,Chennai - 600034,Phone : 044 -28302700 / 28288800\nToll Free No:1800-425-2255 / 1800-102-4477,CIN : L66010TN2005PLC056649 Email :support@starhealth.in  Website :www.starhealth.in\nIRDAI Regn.no: 129\nThis is an electronically generated document(Policy\nSchedule).')]

# %%
prompt_template = """
Write a concise and short summary with in 200 words of the following text:
Text: {text},
"""
template = PromptTemplate(
    template=prompt_template,
    input_variables=["text"]
)
final_prompt = """
Provide the final summary for the text provided in the following points below.
Add a title to the summary.
Points: {text}
"""
final_template = PromptTemplate(
    template=final_prompt,
    input_variables=["text"]
)
chain = load_summarize_chain(
    llm=llm,
    chain_type="map_reduce",
    verbose=True,
    map_prompt=template,
    combine_prompt=final_template,
)

# %%
summary = chain.run(text_splitter)
# Out:
# > Entering new MapReduceDocumentsChain chain...
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
#
# Write a concise and short summary with in 200 words of the following text:
# Text: Star Health And Allied Insurance Company Limited
# To, IMPORTANT
# ADHAR GUPTA    ,
# S/O Devendra kumar agarwal Hno.9 Achar jaan
# Bijnor
# Bijnor Tehsil,Uttar Pradesh-246701
# Mobile : 9719213675
# Date : 05-May-2024
# Dear Customer,
# Re:  Health Insurance Policy - 11240279223503
# We are extremely thankful to you for your renewal instructions and payment of premium. We enclose the
# renewed policy based on our records. We would request you to kindly study the renewed policy carefully and
# revert to us if there is any discrepancy to enable us to attend to the same.
# Kindly note that the above request is very important and if we do not hear anything from you within
# 15 days, we would presume that the policy issued by us is in order and the contract is concluded.
# We would like to mention that we have incorporated the name of the intermediary as indicated by you.
# We wish you good health and we look forward to serve you in the days to come.
# With kind regards,
# Authorised Signatory,
#
# Prompt after formatting:
#
# Write a concise and short summary with in 200 words of the following text:
# Text: We wish you good health and we look forward to serve you in the days to come.
# With kind regards,
# Authorised Signatory
#
# In case of a need for hospitalization, kindly prefer our network hospital (list is available in our website) for a
# quick response to your claim request.
# Sum Insured of this Policy is meant for utilization till its expiry.Bearing this aspect in mind,we have no
# doubt,you will choose appropriate hospital,room rent and treatment charges etc.
# However,the ultimate decision will be that of yours only.
# Please select the room as per your eligibility stipulated in your policy to avoid  additional payment
# from your pocket towards the proportionate increase which would invariably be charged by the
# hospital for the higher room category occupied.
# Should you need any assistance, our customer care will be delighted to assist you ,whose toll free no. is
# 1800-425-2255/1800-102-4477.
# Page 1 of 6,
#
# Prompt after formatting:
#
# Write a concise and short summary with in 200 words of the following text:
# Text: hospital for the higher room category occupied.
# Should you need any assistance, our customer care will be delighted to assist you ,whose toll free no. is
# 1800-425-2255/1800-102-4477.
# Page 1 of 6
# Regd.&Corporate Office:1,New Tank Street,Valluvar Kottam High Road,Nungambakkam,Chennai - 600034,Phone : 044 -28302700 / 28288800
# Toll Free No:1800-425-2255 / 1800-102-4477,CIN : L66010TN2005PLC056649 Email :support@starhealth.in  Website :www.starhealth.in
# IRDAI Regn.no: 129
# This is an electronically generated document(Policy
# Schedule).,
#
# Prompt after formatting:
#
# Write a concise and short summary with in 200 words of the following text:
# Text: Star Health And Allied Insurance Company Limited
# Star Super Surplus (Floater) Insurance Policy
# Unique Identification No. SHAHLIP22034V062122
# Renewal Endorsement No:11240279223503
# Customer Code : GSTIN : 09AAJCS4517L1ZW21775106
# Proposer Code : 21775106 Issuing Office Code : 231119
# Issuing Office Name : Branch Office - MoradabadProposer Name : ADHAR GUPTA
# Shop No. 2 & 3, 2nd Floor,
# Mittal Complex, Above ICICI
# Bank,
# Delhi Road, Moradabad
# Moradabad Tehsil Uttar
# Pradesh 244001
# :Issuing Office AddressS/O Devendra kumar agarwal
# Hno.9 Achar jaan
# Bijnor
# Bijnor Tehsil Uttar Pradesh 246701
# Proposer Address:
# 0591-2487007Phone No :9719213675Phone No :
# : moradabad@starhealth.inE-mail Idaamodkumar69@yahoo.inE-mail Id :
# NO:Proposer GSTIN
# : 08-May-2021Proposal date Fulfiller Code : SH24290
# Place of Supply Uttar Pradesh:
# In Consideration of payment of Rs. 11,894/- towards renewal premium of policy
# number:11240279223502, the policy stands renewed for a further period of 1 Year as per the details,
#
# Prompt after formatting:
#
# Write a concise and short summary with in 200 words of the following text:
# Text: In Consideration of payment of Rs. 11,894/- towards renewal premium of policy
# number:11240279223502, the policy stands renewed for a further period of 1 Year as per the details
# given below
# SAC Code : 997133 / Accident and Health
# Insurance Services
# Customer Name : ADHAR GUPTA
# Cust CKYC No : 60036496137188
# BA0000169109Intermediary
# Code
# :Third Year:Renewal Year
# Collection No 231119/RV/2025/0125330024:
# 05-May-2024Collection Date :
# Date of Inception
# of first policy
# 08-May-2021:
# : AAMOD KUMARName: 10,080/-Premium Rs.
# :Phone No 9412855891CGST @ 9% : Rs. 907/-
# :aamodkumar69@yaho
# o.in
# E-mail Id: Rs. 907/-SGST @ 9%
# Re. 1/-Stamp Duty :
# Total Premium : Rs. 11,894/-
# Total Premium In Words : Rupees Eleven thousand eight hundred ninety four
# only
# PERIOD OF INSURANCE : From : 08-May-2024   00:00 :To Midnight Of 07-May-2025 Policy Term :1 Year
# Installment Facility Option:No Premium Payment Frequency :Annual Installment Amount Rs. : 0/-
# Sum Insured  : Rs. 25,00,000 Defined Limit (Rs.)  : 5,00,000,
#
# Prompt after formatting:
#
# Write a concise and short summary with in 200 words of the following text:
# Text: Installment Facility Option:No Premium Payment Frequency :Annual Installment Amount Rs. : 0/-
# Sum Insured  : Rs. 25,00,000 Defined Limit (Rs.)  : 5,00,000
# Sum Insured in words  : Indian Rupees Twenty Five lakhs  only
# Plan Type  : Family Size  : 2A+2CGOLD
# Entered by
# :  PORTAL
# For Star Health and Allied Insurance Company Ltd.
# Approved by
# :  CUSTPORTAL
# Authorised Signatory
#
# Page 2 of 6
# Email ID: info@starhealth.in
# IRDAI Regn.No.129
# Corporate Identity Number L66010TN2005PLC056649
# Regd.&Corporate Office:1,New Tank Street,Valluvar Kottam High Road,Nungambakkam,Chennai - 600034,Phone : 044 -28302700 / 28288800
# Toll Free No:1800-425-2255 / 1800-102-4477,CIN : L66010TN2005PLC056649 Email :support@starhealth.in  Website :www.starhealth.in
# IRDAI Regn.no: 129
# This is an electronically generated document(Policy
# Schedule).,
#
# Prompt after formatting:
#
# Write a concise and short summary with in 200 words of the following text:
# Text: Star Health And Allied Insurance Company Limited
# Attached to and forming part of Policy No:  11240279223503
# Details of Insured Persons :
# ID Card NoAge in
# YrsDate of Birth Inception
# date
# Sl.
# no. Name of the Insured Relationship
# with ProposerGender
# 1 ADHAR GUPTA Male 26-Nov-1976 47 Self 21775106-1 08-May-2021
# No PED DeclaredPre Existing Disease :
# 2 SHALINI GUPTA Female 06-Aug-1979 44 Spouse 21775106-2 08-May-2021
# No PED DeclaredPre Existing Disease :
# 3 DIVIK GUPTA Male 05-Aug-2004 19 Son 21775106-3 08-May-2021
# No PED DeclaredPre Existing Disease :
# 4 MADHAV GUPTA Male 12-May-2008 15 Son 21775106-4 08-May-2021
# No PED DeclaredPre Existing Disease :
# Nominee Details:
# S.No Name Relationship
# with proposer
# Age % of the
# claim
# Appointee Name Appointee
# Age
# Relationship
# with nominee
# 1 SHALINI GUPTA Spouse 44 100
# Nominee Details for the Proposer Appointee Details
# Urban
# Sector Classification:,
#
# Prompt after formatting:
#
# Write a concise and short summary with in 200 words of the following text:
# Text: with proposer
# Age % of the
# claim
# Appointee Name Appointee
# Age
# Relationship
# with nominee
# 1 SHALINI GUPTA Spouse 44 100
# Nominee Details for the Proposer Appointee Details
# Urban
# Sector Classification:
# Please check whether the details given by you about the Insured persons in the Proposal Form are incorporated
# correctly in the Policy.If you find any discrepancy , please inform us within 15 days from the date of receipt of the
# policy, failing which the details relating to the Insured persons given  in the Policy are deemed to have been
# accepted by you.
# Warranted that in case of dishonour of premium cheque(s) the Company shall not be liable under the policy and
# the policy shall be void abinitio.
# Important
# In the event of hospitalization of insured person, intimation should be given to the Company immediately,
# however, within 24 hrs from the time of admission.
# Toll Free No:1800 425 2255/1800 102 4477 Email: support@starhealth.in, Fax No: 1800 425 5522.,
#
# Prompt after formatting:
#
# Write a concise and short summary with in 200 words of the following text:
# Text: however, within 24 hrs from the time of admission.
# Toll Free No:1800 425 2255/1800 102 4477 Email: support@starhealth.in, Fax No: 1800 425 5522.
# It is hereby made clear that all terms, conditions, clauses, warranties, exclusions etc., as already issued, forming
# part of the policy of insurance originally issued at the time of inception of this relationship, shall continue to be
# operative and unaltered, forming part of this renewal insurance cover also.
# Reference may be made to those terms, conditions etc., for identifying the scope/extent of coverage.
# Other excluded expenses as detailed in our website www.starhealth.in
# In witness whereof the undersigned being authorized here in to set his hand at Branch Office - Moradabad on 05th
# Day of  May 2024.
# Entered by
# :  PORTAL
# For Star Health and Allied Insurance Company Ltd.
# Approved by
# :  CUSTPORTAL
# Authorised Signatory
#
# Page 3 of 6,
#
# Prompt after formatting:
#
# Write a concise and short summary with in 200 words of the following text:
# Text: Day of  May 2024.
# Entered by
# :  PORTAL
# For Star Health and Allied Insurance Company Ltd.
# Approved by
# :  CUSTPORTAL
# Authorised Signatory
#
# Page 3 of 6
# Regd.&Corporate Office:1,New Tank Street,Valluvar Kottam High Road,Nungambakkam,Chennai - 600034,Phone : 044 -28302700 / 28288800
# Toll Free No:1800-425-2255 / 1800-102-4477,CIN : L66010TN2005PLC056649 Email :support@starhealth.in  Website :www.starhealth.in
# IRDAI Regn.no: 129
# This is an electronically generated document(Policy
# Schedule).,
#
# Prompt after formatting:
#
# Write a concise and short summary with in 200 words of the following text:
# Text: Star Health And Allied Insurance Company Limited
# As per Section 34 of CGST Act of 2017, Policy Issued in one Financial Year and Cancelled in another Financial Year
# on or after 01st of December, then Only Premium Amount will be Refunded to the Customer and GST Amount will
# Not be Refunded. Customer has to Claim the Refund of GST Amount from the GST Portal.
# Entered by
# :  PORTAL
# For Star Health and Allied Insurance Company Ltd.
# Approved by
# :  CUSTPORTAL
# Authorised Signatory
#
# Page 4 of 6
# Regd.&Corporate Office:1,New Tank Street,Valluvar Kottam High Road,Nungambakkam,Chennai - 600034,Phone : 044 -28302700 / 28288800
# Toll Free No:1800-425-2255 / 1800-102-4477,CIN : L66010TN2005PLC056649 Email :support@starhealth.in  Website :www.starhealth.in
# IRDAI Regn.no: 129
# This is an electronically generated document(Policy
# Schedule).,
#
# Prompt after formatting:
#
# Write a concise and short summary with in 200 words of the following text:
# Text: Star Health And Allied Insurance Company Limited
# 231119-Branch Office - MoradabadIssue Office :
# Shop No. 2 & 3, 2nd Floor,
# Mittal Complex, Above ICICI Bank,
# Delhi Road, Moradabad
# Moradabad Tehsil Uttar Pradesh 244001
# Address :
# 0591-2487007Tel / Fax :
# moradabad@starhealth.inEmail :
# This is to certify that ADHAR GUPTA     has paid Rs 11,894/- (Total Premium : Indian Rupees Eleven thousand
# eight hundred ninety four only ) towards Premium for Hospitalization Insurance vide Policy No:
# 11240279223503 for the Period 08-May-2024 To 07-May-2025 issued on 05-May-2024.
# Payment received by Payment Gateway vide Receipt No: 231119/RV/2025/0125330024/1 Receipt
# Date: 05-May-2024
# This Certificate must be surrendered to the Insurance Company for issuance of fresh Certificate in
# case of Cancellation of the Policy or any alteration in the Insurance affecting the Premium.
# Note :-
# Hospitalisation Benefit Policy,
#
# Prompt after formatting:
#
# Write a concise and short summary with in 200 words of the following text:
# Text: case of Cancellation of the Policy or any alteration in the Insurance affecting the Premium.
# Note :-
# Hospitalisation Benefit Policy
# Premium Certificate for the purpose of deduction under Section 80 D of Income Tax (Amendment) Act,1986
# Authorised Signatory
# For and on behalf of
# Place : Branch Office - Moradabad
# Date : 05-May-2024
#
# Star Health and Allied Insurance Company Ltd.
# IRDA Regn.No.129
# Email ID: info@starhealth.in
# Corporate Identity Number L66010TN2005PLC056649
# Policy No : Type of Policy  :11240279223503 Super Surplus Floater Revised-
# 2021
# Entered by
# :  PORTAL
# For Star Health and Allied Insurance Company Ltd.
# Approved by
# :  CUSTPORTAL
# Authorised Signatory
#
# Page 5 of 6
# Regd.&Corporate Office:1,New Tank Street,Valluvar Kottam High Road,Nungambakkam,Chennai - 600034,Phone : 044 -28302700 / 28288800
# Toll Free No:1800-425-2255 / 1800-102-4477,CIN : L66010TN2005PLC056649 Email :support@starhealth.in  Website :www.starhealth.in
# IRDAI Regn.no: 129,
#
# Prompt after formatting:
#
# Write a concise and short summary with in 200 words of the following text:
# Text: Toll Free No:1800-425-2255 / 1800-102-4477,CIN : L66010TN2005PLC056649 Email :support@starhealth.in  Website :www.starhealth.in
# IRDAI Regn.no: 129
# This is an electronically generated document(Policy
# Schedule).,
#
# Prompt after formatting:
#
# Write a concise and short summary with in 200 words of the following text:
# Text: Star Health And Allied Insurance Company Limited
# Tax Invoice
# Recipient Supplier
# GSTIN GSTIN 09AAJCS4517L1ZW::
# Name ADHAR GUPTA Name Star Health and Allied Insurance Co Ltd -
# Branch Office - Moradabad
# ::
# Address S/O Devendra kumar agarwal Hno.9
# Achar jaan
# Address Shop No. 2 & 3, 2nd Floor,::
# Bijnor Mittal Complex, Above ICICI Bank,
#  Delhi Road, Moradabad
# : Bijnor TehsilCity Pin Code  :  246701 : Moradabad
# Tehsil
# City Pin Code 244001:
# : Uttar PradeshState Place of
# supply
# Uttar Pradesh:: Uttar Pradesh State Client
# Category
#  IND:
# Invoice No. 092405I003493898 Customer ID 21775106::
# Invoice Date 05-May-2024 Policy No. 11240279223503::
# This is a digitally signed document and hence no physical signature is required
# IRDAI Regn.No.129 Email ID: stargst@starhealth.inCorporate Identity Number L66010TN2005PLC056649
# Important Note:
# The invoice is issued as per Section 31 of the CGST Act,
#
# Prompt after formatting:
#
# Write a concise and short summary with in 200 words of the following text:
# Text: IRDAI Regn.No.129 Email ID: stargst@starhealth.inCorporate Identity Number L66010TN2005PLC056649
# Important Note:
# The invoice is issued as per Section 31 of the CGST Act
# In case no GSTIN or incorrect GSTIN is provided by the Proposer at Proposal stage, Star Health and Allied Insurance Co Ltd shall not be
# responsible for any Input Tax Credit losses and no subsequent revision of invoice will be undertaken
# "I/We hereby declare that though our aggregate turnover in any preceding financial year from 2017-18 onwards is more than the aggregate
# turnover notified under sub-rule (4) of rule 48, we are not required to prepare an invoice in terms of the provisions of the said sub-rule."
# E. & O.E
#
# Total Invoice Value (in Figures) Rs. 11,894/-:
# Total Invoice Value (in Words) Rupees Eleven thousand eight hundred ninety four only:
# Amount of Tax Subject to reverse Charge No:
# B C = A - B D = C *
# IGST
# E = C *
# CGST
# F = C *
# UTGST or
# SGST
# Discount Taxable
# Value
# IGST @
# 18% CGST @ 9% UT/SGST @
# 9%
# H = C + D +,
#
# Prompt after formatting:
#
# Write a concise and short summary with in 200 words of the following text:
# Text: Amount of Tax Subject to reverse Charge No:
# B C = A - B D = C *
# IGST
# E = C *
# CGST
# F = C *
# UTGST or
# SGST
# Discount Taxable
# Value
# IGST @
# 18% CGST @ 9% UT/SGST @
# 9%
# H = C + D +
# E+ F + G
# Description of
# Service(s)
# HSN / SAC
# Code
# Total
# A
# Total Invoice
# Value
# CESS @
# 1%
# G= C *
# Cess
# 997133 Insurance
# Services 10,080.00 0 10,080.00 0 907.00 907.00 11,894.000
# Entered by
# :  PORTAL
# For Star Health and Allied Insurance Company Ltd.
# Approved by
# :  CUSTPORTAL
# Authorised Signatory
#
# Page 6 of 6
# Regd.&Corporate Office:1,New Tank Street,Valluvar Kottam High Road,Nungambakkam,Chennai - 600034,Phone : 044 -28302700 / 28288800
# Toll Free No:1800-425-2255 / 1800-102-4477,CIN : L66010TN2005PLC056649 Email :support@starhealth.in  Website :www.starhealth.in
# IRDAI Regn.no: 129
# This is an electronically generated document(Policy
# Schedule).,
# Token indices sequence length is longer than the specified maximum sequence length for this model (2712 > 1024). Running this sequence through the model will result in indexing errors
# > Finished chain.
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
#
# Provide the final summary for the text provided in the following points below.
# Add a title to the summary.
# Points: Here is a concise and short summary of the text within 200 words:
#
# Star Health and Allied Insurance Company Limited has sent a renewal notice to Adhar Gupta for his health insurance policy (11240279223503). The policy has been renewed based on the company's records, and a copy is enclosed. The company requests Adhar to carefully review the renewed policy and report any discrepancies to enable them to address the issues. The company emphasizes the importance of this request and advises that if they do not receive a response within 15 days, they will presume that the policy is in order and the contract is concluded. Additionally, the company has incorporated the name of the intermediary as indicated by Adhar. The company wishes Adhar good health and looks forward to serving him in the future.
#
# Here is a concise and short summary of the text within 200 words:
#
# The message starts by wishing the policyholder good health and expressing readiness to serve them in the future. It also reminds them to use their network hospital for any hospitalization needs, making it easier to process their claim request. The policy's sum insured is meant to be used until its expiration date, and the policyholder is free to choose their hospital, room rent, and treatment charges. However, the policyholder is advised to select a room according to their policy's eligibility to avoid additional payments. If the policyholder needs assistance, they can contact the customer care team at 1800-425-2255 or 1800-102-4477.
#
# Here is a concise and short summary of the text within 200 words:
#
# This is a policy schedule for a hospital that caters to the higher room category. If customers need assistance, they can contact the customer care team at toll-free numbers 1800-425-2255 or 1800-102-4477. The company's registered and corporate office is located at 1, New Tank Street, Valluvar Kottam High Road, Nungambakkam, Chennai - 600034. The contact information includes a phone number (044-28302700 / 28288800) and email address (support@starhealth.in). The company's website is www.starhealth.in and its IRDAI registration number is 129. This is an electronically generated document, which is the policy schedule.
#
# Here is a concise and short summary of the text within 200 words:
#
# Star Health And Allied Insurance Company Limited has renewed a Star Super Surplus (Floater) Insurance Policy for a customer, Adhar Gupta, for a further period of 1 year. The renewal premium paid is Rs. 11,894/-. The policy is unique identified by SHAHLIP22034V062122 and has a renewal endorsement number of 11240279223503. The customer's details include their GSTIN, phone number, and email ID. The policy is issued from the Branch Office in Moradabad and the proposer's address is in Bijnor, Uttar Pradesh. The policy was renewed on a proposal date of May 8, 2021.
#
# Here is a concise and short summary of the text within 200 words:
#
# A policy with number 11240279223502 has been renewed for a further period of 1 year, effective from May 8, 2024, to May 7, 2025. The policy is owned by Adhar Gupta, with a customer KYC number of 60036496137188. The policy is an Accident and Health Insurance Service, with a premium of Rs. 11,894/-, which includes CGST and SGST. The stamp duty is Rs. 1/-. The sum insured is Rs. 25,00,000, with a defined limit of Rs. 5,00,000. There is no installment facility option, and the premium is paid annually. The policy details are as follows: SAC Code 997133, Customer Name Adhar Gupta, Cust CKYC No 60036496137188, and Intermediary Code BA0000169109.
#
# Here is a concise summary of the text in 200 words or less:
#
# This is a policy schedule for an Installment Facility Option with Star Health and Allied Insurance Company Ltd. The policy has an annual installment amount of Rs. 0/- and a sum insured of Rs. 25,00,000. The defined limit is Rs. 5,00,000. The policy is for a family size of 2A+2C and is a GOLD plan. The policy was entered through the PORTAL and approved by CUSTPORTAL. The policy details are as follows: sum insured in words is "Indian Rupees Twenty Five lakhs only", plan type is Family, and the frequency of premium payment is annual. The policy was generated electronically and is a document issued by the insurance company. The company's contact information is also provided, including email, phone numbers, and website.
#
# Here is a concise and short summary of the text within 200 words:
#
# The document is a policy summary for Star Health And Allied Insurance Company Limited, Policy No: 11240279223503. It lists the insured persons, including Adhar Gupta (age 47), Shalini Gupta (age 44), Divik Gupta (age 19), and Madhav Gupta (age 15). Each person's ID card number, date of birth, and inception date are provided. There are no pre-existing diseases declared for any of the insured persons. The policy also includes nominee details, with Shalini Gupta named as the nominee and appointee, with a 100% claim percentage. The sector classification is urban. The policy was initiated on May 8, 2021.
#
# Here is a concise and short summary of the text in 200 words:
#
# The document appears to be a life insurance policy proposal form. It contains details about the proposer, appointee, and nominee. The proposer, Shalini Gupta, is the spouse of the appointee and 44 years old. The policy is classified as urban and requires the proposer to ensure the details provided in the proposal form are accurate. If any discrepancies are found, the proposer must notify the company within 15 days. The policy is void if the premium cheque is dishonoured. In case of hospitalization, the insured person must notify the company immediately, but within 24 hours of admission. The company provides a toll-free number, email, and fax number for support.
#
# Here is a concise and short summary of the text within 200 words:
#
# This document is a renewal of an insurance policy with Star Health and Allied Insurance Company Ltd. The terms and conditions of the original policy, including warranties, exclusions, and other clauses, remain unchanged and continue to apply to this renewal. The scope and extent of coverage can be identified by referencing the original terms and conditions. The policy does not cover certain expenses, which are detailed on the company's website (www.starhealth.in). If you have any questions or concerns, you can contact the company at 1800 425 2255/1800 102 4477 or email support@starhealth.in.
#
# Here is a concise and short summary of the text within 200 words:
#
# This is a Policy Schedule document dated May 2024, provided by Star Health and Allied Insurance Company Ltd. The document was entered through the PORTAL and approved by CUSTPORTAL. The authorized signatory is listed, but not mentioned in the summary. The company's registration and corporate office details are provided, including their address, phone numbers, toll-free numbers, CIN, and IRDAI registration number. The document is electronically generated and notes that it is a Policy Schedule. The company's website and email address are also listed. This summary provides a brief overview of the document's contents, excluding the authorized signatory and the detailed company information.
#
# Here is a concise and short summary of the text within 200 words:
#
# According to the CGST Act of 2017, if a policy is issued in one financial year and cancelled in another financial year, only the premium amount will be refunded to the customer. The GST amount will not be refunded, and the customer must claim it from the GST Portal. This policy is governed by Section 34 of the CGST Act. The document is electronically generated and is a policy schedule.
#
# Here is a concise and short summary of the text within 200 words:
#
# Star Health And Allied Insurance Company Limited has issued a hospitalization insurance policy to Adhar Gupta. The policy number is 11240279223503 and it covers the period from May 8, 2024, to May 7, 2025. The policy was issued on May 5, 2024, and Adhar Gupta paid a premium of Rs. 11,894. The payment was received through a payment gateway with receipt number 231119/RV/2025/0125330024/1 and receipt date May 5, 2024. This certificate must be surrendered to the insurance company in case of policy cancellation or any changes that affect the premium. The policy is a hospitalization benefit policy.
#
# Here is a concise and short summary of the text within 200 words:
#
# This document is a Premium Certificate for a Hospitalisation Benefit Policy, specifically a Super Surplus Floater Revised-2021 policy with policy number 11240279223503. The policy was entered through the PORTAL and approved by CUSTPORTAL. The document is issued by Star Health and Allied Insurance Company Ltd. and is registered under IRDA Regn.No.129. The policy is effective and valid. If the policy is cancelled or altered, the premium may be affected. The document includes information about the authorized signatory, date, and place of issuance. It also includes contact details of the company, including their email ID, corporate office address, and phone numbers. The document is part of the policy and is used for the purpose of deduction under Section 80 D of the Income Tax (Amendment) Act, 1986.
#
# Here is a concise and short summary of the text:
#
# Star Health and Allied Insurance Company provides insurance services and can be contacted through their toll-free numbers (1800-425-2255 and 1800-102-4477). Their corporate information includes a CIN (L66010TN2005PLC056649), email address (support@starhealth.in), and website (www.starhealth.in). They are registered with the Insurance Regulatory and Development Authority of India (IRDAI) with registration number 129. This document is an electronically generated policy schedule.
#
# Here is a concise summary of the text in 200 words:
#
# This is a tax invoice from Star Health and Allied Insurance Company Limited, with GSTIN 09AAJCS4517L1ZW. The invoice is issued to Adhar Gupta, with a customer ID 21775106, and policy number 11240279223503. The invoice date is May 5, 2024. The document is digitally signed and does not require a physical signature. The invoice is issued as per Section 31 of the Central Goods and Services Tax (CGST) Act. The company's details include its corporate identity number L66010TN2005PLC056649, IRDAI registration number 129, and email ID stargst@starhealth.in. The invoice is for supplies made in the state of Uttar Pradesh, specifically from the Moradabad branch office.
#
# Here is a concise summary of the text within 200 words:
#
# This is an invoice issued by Star Health and Allied Insurance Co Ltd, registered with IRDAI. The invoice is issued as per Section 31 of the CGST Act. The proposer is required to provide their GSTIN, as any errors or omissions may result in Input Tax Credit losses and subsequent revisions of the invoice will not be undertaken. The invoice value is Rs. 11,894 and includes IGST, CGST, and UT/SGST taxes. The taxes are calculated at 18% IGST, 9% CGST, and 9% UT/SGST. There is no discount or tax subject to reverse charge. The invoice is subject to errors and omissions, and the proposer is required to prepare an invoice in accordance with the CGST Act.
#
# Here is a concise and short summary of the text within 200 words:
#
# This document is a policy schedule for insurance services provided by Star Health and Allied Insurance Company Ltd. The policy details include the amount of tax subject to reverse charge, which is calculated as follows: IGST (18%), CGST (9%), and UT/SGST (9%). The total invoice value is ₹10,080.00, with a discount taxable value of ₹907.00. The cess is calculated at 1% of the total invoice value. The policy details also include the description of services, HSN/SAC code, and total value. The document is electronically generated and approved by the authorized signatory. It is a policy schedule and not a physical document. The company information, including its registered office address, phone numbers, and email, is also provided.
#
#
# > Finished chain.
#
# > Finished chain.

# %%
print(summary)
# Out:
# **Summary: Star Health and Allied Insurance Company Policy Renewal and Updates**
#
# Star Health and Allied Insurance Company Limited has sent a renewal notice to Adhar Gupta for his health insurance policy (11240279223503). The company requests Adhar to review the renewed policy and report any discrepancies. The company has incorporated the name of the intermediary as indicated by Adhar and wishes him good health. The policy's sum insured is meant to be used until its expiration date, and the policyholder is free to choose their hospital, room rent, and treatment charges. The company has provided various contact details, including phone numbers, email addresses, and a website, for any assistance or queries.

# %%
## Refine Chain Summarization

chain = load_summarize_chain(
    llm=llm,
    chain_type="refine",
    verbose=True
)

summary = chain.run(text_splitter)
# Out:
# > Entering new RefineDocumentsChain chain...
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# Write a concise summary of the following:
#
#
# "Star Health And Allied Insurance Company Limited
# To, IMPORTANT
# ADHAR GUPTA    ,
# S/O Devendra kumar agarwal Hno.9 Achar jaan
# Bijnor
# Bijnor Tehsil,Uttar Pradesh-246701
# Mobile : 9719213675
# Date : 05-May-2024
# Dear Customer,
# Re:  Health Insurance Policy - 11240279223503
# We are extremely thankful to you for your renewal instructions and payment of premium. We enclose the
# renewed policy based on our records. We would request you to kindly study the renewed policy carefully and
# revert to us if there is any discrepancy to enable us to attend to the same.
# Kindly note that the above request is very important and if we do not hear anything from you within
# 15 days, we would presume that the policy issued by us is in order and the contract is concluded.
# We would like to mention that we have incorporated the name of the intermediary as indicated by you.
# We wish you good health and we look forward to serve you in the days to come.
# With kind regards,
# Authorised Signatory"
#
#
# CONCISE SUMMARY:
#
# > Finished chain.
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# Your job is to produce a final summary.
# We have provided an existing summary up to a certain point: Here is a concise summary:
#
# Star Health Insurance Company has renewed an existing health insurance policy (11240279223503) for Adhar Gupta, based on his payment and renewal instructions. They request him to review the renewed policy carefully and report any discrepancies. If they don't hear back within 15 days, they will assume the policy is in order and the contract is concluded.
# We have the opportunity to refine the existing summary (only if needed) with some more context below.
# ------------
# We wish you good health and we look forward to serve you in the days to come.
# With kind regards,
# Authorised Signatory
#
# In case of a need for hospitalization, kindly prefer our network hospital (list is available in our website) for a
# quick response to your claim request.
# Sum Insured of this Policy is meant for utilization till its expiry.Bearing this aspect in mind,we have no
# doubt,you will choose appropriate hospital,room rent and treatment charges etc.
# However,the ultimate decision will be that of yours only.
# Please select the room as per your eligibility stipulated in your policy to avoid  additional payment
# from your pocket towards the proportionate increase which would invariably be charged by the
# hospital for the higher room category occupied.
# Should you need any assistance, our customer care will be delighted to assist you ,whose toll free no. is
# 1800-425-2255/1800-102-4477.
# Page 1 of 6
# ------------
# Given the new context, refine the original summary.
# If the context isn't useful, return the original summary.
#
# > Finished chain.
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# Your job is to produce a final summary.
# We have provided an existing summary up to a certain point: Here is a refined summary based on the additional context:
#
# Star Health Insurance Company has renewed an existing health insurance policy (11240279223503) for Adhar Gupta, effective [date of renewal]. The company requests him to carefully review the renewed policy and report any discrepancies. If no response is received within 15 days, it will be assumed that the policy is in order and the contract is concluded. As a policyholder, Adhar Gupta is advised to utilize the Sum Insured within the policy's expiry date. The company encourages him to choose a hospital from their network list (available on their website) for a quicker claim processing. Additionally, Adhar Gupta is advised to select a room category in accordance with his policy's eligibility to avoid additional payments. For any assistance or queries, he can contact the customer care team on toll-free numbers 1800-425-2255/1800-102-4477.
#
# The original summary remains the same, with the additional context providing more details about the policy renewal and hospital selection. The refined summary aims to provide a clear and concise overview of the policy renewal and the company's requirements.
# We have the opportunity to refine the existing summary (only if needed) with some more context below.
# ------------
# hospital for the higher room category occupied.
# Should you need any assistance, our customer care will be delighted to assist you ,whose toll free no. is
# 1800-425-2255/1800-102-4477.
# Page 1 of 6
# Regd.&Corporate Office:1,New Tank Street,Valluvar Kottam High Road,Nungambakkam,Chennai - 600034,Phone : 044 -28302700 / 28288800
# Toll Free No:1800-425-2255 / 1800-102-4477,CIN : L66010TN2005PLC056649 Email :support@starhealth.in  Website :www.starhealth.in
# IRDAI Regn.no: 129
# This is an electronically generated document(Policy
# Schedule).
# ------------
# Given the new context, refine the original summary.
# If the context isn't useful, return the original summary.
#
# > Finished chain.
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# Your job is to produce a final summary.
# We have provided an existing summary up to a certain point: Based on the new context, I refined the original summary as follows:
#
# Star Health Insurance Company has renewed an existing health insurance policy (11240279223503) for Adhar Gupta, effective [date of renewal]. The company requests him to carefully review the renewed policy and report any discrepancies. If no response is received within 15 days, it will be assumed that the policy is in order and the contract is concluded. As a policyholder, Adhar Gupta is advised to utilize the Sum Insured within the policy's expiry date. It is also important to note that he should choose a hospital from their network list (available on their website) for a quicker claim processing. Additionally, he should select a room category in accordance with his policy's eligibility to avoid additional payments. In case of any query or assistance, he can contact the customer care team on toll-free numbers 1800-425-2255/1800-102-4477.
# We have the opportunity to refine the existing summary (only if needed) with some more context below.
# ------------
# Star Health And Allied Insurance Company Limited
# Star Super Surplus (Floater) Insurance Policy
# Unique Identification No. SHAHLIP22034V062122
# Renewal Endorsement No:11240279223503
# Customer Code : GSTIN : 09AAJCS4517L1ZW21775106
# Proposer Code : 21775106 Issuing Office Code : 231119
# Issuing Office Name : Branch Office - MoradabadProposer Name : ADHAR GUPTA
# Shop No. 2 & 3, 2nd Floor,
# Mittal Complex, Above ICICI
# Bank,
# Delhi Road, Moradabad
# Moradabad Tehsil Uttar
# Pradesh 244001
# :Issuing Office AddressS/O Devendra kumar agarwal
# Hno.9 Achar jaan
# Bijnor
# Bijnor Tehsil Uttar Pradesh 246701
# Proposer Address:
# 0591-2487007Phone No :9719213675Phone No :
# : moradabad@starhealth.inE-mail Idaamodkumar69@yahoo.inE-mail Id :
# NO:Proposer GSTIN
# : 08-May-2021Proposal date Fulfiller Code : SH24290
# Place of Supply Uttar Pradesh:
# In Consideration of payment of Rs. 11,894/- towards renewal premium of policy
# number:11240279223502, the policy stands renewed for a further period of 1 Year as per the details
# ------------
# Given the new context, refine the original summary.
# If the context isn't useful, return the original summary.
#
# > Finished chain.
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# Your job is to produce a final summary.
# We have provided an existing summary up to a certain point: Based on the new context, I refined the original summary as follows:
#
# Star Health Insurance Company has renewed the Star Super Surplus (Floater) Insurance Policy (Unique Identification No. SHAHLIP22034V062122) for Adhar Gupta, effective [date of renewal]. The policy was renewed for a further period of 1 year upon payment of a renewal premium of Rs. 11,894/- for policy number 11240279223502. The company requests Adhar Gupta to carefully review the renewed policy and report any discrepancies. If no response is received within 15 days, it will be assumed that the policy is in order and the contract is concluded. As a policyholder, Adhar Gupta is advised to utilize the Sum Insured within the policy's expiry date. It is also important to note that he should choose a hospital from Star Health's network list (available on their website) for a quicker claim processing. Additionally, he should select a room category in accordance with his policy's eligibility to avoid additional payments. In case of any query or assistance, Adhar Gupta can contact the customer care team on toll-free numbers 1800-425-2255/1800-102-4477.
# We have the opportunity to refine the existing summary (only if needed) with some more context below.
# ------------
# In Consideration of payment of Rs. 11,894/- towards renewal premium of policy
# number:11240279223502, the policy stands renewed for a further period of 1 Year as per the details
# given below
# SAC Code : 997133 / Accident and Health
# Insurance Services
# Customer Name : ADHAR GUPTA
# Cust CKYC No : 60036496137188
# BA0000169109Intermediary
# Code
# :Third Year:Renewal Year
# Collection No 231119/RV/2025/0125330024:
# 05-May-2024Collection Date :
# Date of Inception
# of first policy
# 08-May-2021:
# : AAMOD KUMARName: 10,080/-Premium Rs.
# :Phone No 9412855891CGST @ 9% : Rs. 907/-
# :aamodkumar69@yaho
# o.in
# E-mail Id: Rs. 907/-SGST @ 9%
# Re. 1/-Stamp Duty :
# Total Premium : Rs. 11,894/-
# Total Premium In Words : Rupees Eleven thousand eight hundred ninety four
# only
# PERIOD OF INSURANCE : From : 08-May-2024   00:00 :To Midnight Of 07-May-2025 Policy Term :1 Year
# Installment Facility Option:No Premium Payment Frequency :Annual Installment Amount Rs. : 0/-
# Sum Insured  : Rs. 25,00,000 Defined Limit (Rs.)  : 5,00,000
# ------------
# Given the new context, refine the original summary.
# If the context isn't useful, return the original summary.
#
# > Finished chain.
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# Your job is to produce a final summary.
# We have provided an existing summary up to a certain point: Based on the new context, I have refined the original summary as follows:
#
# Star Health Insurance Company has renewed the Star Super Surplus (Floater) Insurance Policy (Unique Identification No. SHAHLIP22034V062122) for Adhar Gupta, effective [date of renewal]. The policy was renewed for a further period of 1 year upon payment of a renewal premium of Rs. 11,894/- for policy number 11240279223502. The company requests Adhar Gupta to carefully review the renewed policy and report any discrepancies. If no response is received within 15 days, it will be assumed that the policy is in order and the contract is concluded. As a policyholder, Adhar Gupta is advised to utilize the Sum Insured within the policy's expiry date. It is also important to note that he should choose a hospital from Star Health's network list (available on their website) for a quicker claim processing. Additionally, he should select a room category in accordance with his policy's eligibility to avoid additional payments. In case of any query or assistance, Adhar Gupta can contact the customer care team on toll-free numbers 1800-425-2255/1800-102-4477.
#
# The policy details are as follows:
#
# * Policy number: 11240279223502
# * Policy term: 1 year
# * Sum Insured: Rs. 25,00,000
# * Defined Limit: Rs. 5,00,000
# * Period of insurance: From 08-May-2024 to 07-May-2025
# * Premium payment frequency: Annual
# * Total premium: Rs. 11,894/-
#
# Please review the policy and report any discrepancies within 15 days. If no response is received, it will be assumed that the policy is in order and the contract is concluded.
# We have the opportunity to refine the existing summary (only if needed) with some more context below.
# ------------
# Installment Facility Option:No Premium Payment Frequency :Annual Installment Amount Rs. : 0/-
# Sum Insured  : Rs. 25,00,000 Defined Limit (Rs.)  : 5,00,000
# Sum Insured in words  : Indian Rupees Twenty Five lakhs  only
# Plan Type  : Family Size  : 2A+2CGOLD
# Entered by
# :  PORTAL
# For Star Health and Allied Insurance Company Ltd.
# Approved by
# :  CUSTPORTAL
# Authorised Signatory
#
# Page 2 of 6
# Email ID: info@starhealth.in
# IRDAI Regn.No.129
# Corporate Identity Number L66010TN2005PLC056649
# Regd.&Corporate Office:1,New Tank Street,Valluvar Kottam High Road,Nungambakkam,Chennai - 600034,Phone : 044 -28302700 / 28288800
# Toll Free No:1800-425-2255 / 1800-102-4477,CIN : L66010TN2005PLC056649 Email :support@starhealth.in  Website :www.starhealth.in
# IRDAI Regn.no: 129
# This is an electronically generated document(Policy
# Schedule).
# ------------
# Given the new context, refine the original summary.
# If the context isn't useful, return the original summary.
#
# > Finished chain.
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# Your job is to produce a final summary.
# We have provided an existing summary up to a certain point: Here is the refined summary:
#
# Star Health Insurance Company has renewed the Star Super Surplus (Floater) Insurance Policy (Unique Identification No. SHAHLIP22034V062122) for Adhar Gupta, effective [date of renewal]. The policy was renewed for a further period of 1 year upon payment of a renewal premium of Rs. 11,894/- for policy number 11240279223502. The policy details are as follows:
#
# * Policy number: 11240279223502
# * Policy term: 1 year
# * Sum Insured: Rs. 25,00,000
# * Defined Limit: Rs. 5,00,000
# * Period of insurance: From 08-May-2024 to 07-May-2025
# * Premium payment frequency: Annual
# * Total premium: Rs. 11,894/-
#
# Adhar Gupta is advised to carefully review the renewed policy and report any discrepancies within 15 days. If no response is received, it will be assumed that the policy is in order and the contract is concluded. As a policyholder, Adhar Gupta is advised to utilize the Sum Insured within the policy's expiry date and choose a hospital from Star Health's network list (available on their website) for a quicker claim processing. Additionally, he should select a room category in accordance with his policy's eligibility to avoid additional payments.
#
# In case of any query or assistance, Adhar Gupta can contact the customer care team on toll-free numbers 1800-425-2255/1800-102-4477.
# We have the opportunity to refine the existing summary (only if needed) with some more context below.
# ------------
# Star Health And Allied Insurance Company Limited
# Attached to and forming part of Policy No:  11240279223503
# Details of Insured Persons :
# ID Card NoAge in
# YrsDate of Birth Inception
# date
# Sl.
# no. Name of the Insured Relationship
# with ProposerGender
# 1 ADHAR GUPTA Male 26-Nov-1976 47 Self 21775106-1 08-May-2021
# No PED DeclaredPre Existing Disease :
# 2 SHALINI GUPTA Female 06-Aug-1979 44 Spouse 21775106-2 08-May-2021
# No PED DeclaredPre Existing Disease :
# 3 DIVIK GUPTA Male 05-Aug-2004 19 Son 21775106-3 08-May-2021
# No PED DeclaredPre Existing Disease :
# 4 MADHAV GUPTA Male 12-May-2008 15 Son 21775106-4 08-May-2021
# No PED DeclaredPre Existing Disease :
# Nominee Details:
# S.No Name Relationship
# with proposer
# Age % of the
# claim
# Appointee Name Appointee
# Age
# Relationship
# with nominee
# 1 SHALINI GUPTA Spouse 44 100
# Nominee Details for the Proposer Appointee Details
# Urban
# Sector Classification:
# ------------
# Given the new context, refine the original summary.
# If the context isn't useful, return the original summary.
#
# > Finished chain.
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# Your job is to produce a final summary.
# We have provided an existing summary up to a certain point: Based on the new context, I have refined the original summary to provide a more comprehensive overview of the policy details and requirements:
#
# Star Health Insurance Company has renewed the Star Super Surplus (Floater) Insurance Policy (Unique Identification No. SHAHLIP22034V062122) for Adhar Gupta, effective [date of renewal]. The policy was renewed for a further period of 1 year upon payment of a renewal premium of Rs. 11,894/- for policy number 11240279223502.
#
# The policy details are as follows:
#
# * Policy number: 11240279223502
# * Policy term: 1 year
# * Sum Insured: Rs. 25,00,000
# * Defined Limit: Rs. 5,00,000
# * Period of insurance: From 08-May-2024 to 07-May-2025
# * Premium payment frequency: Annual
# * Total premium: Rs. 11,894/-
#
# The policy covers Adhar Gupta and his family members, including his spouse Shalini Gupta and children Divik Gupta, Madhav Gupta. The policy also includes nominee details, with Shalini Gupta as the appointee and 100% of the claim.
#
# As a policyholder, Adhar Gupta is advised to:
#
# * Carefully review the renewed policy and report any discrepancies within 15 days.
# * Utilize the Sum Insured within the policy's expiry date.
# * Choose a hospital from Star Health's network list for a quicker claim processing.
# * Select a room category in accordance with his policy's eligibility to avoid additional payments.
#
# In case of any query or assistance, Adhar Gupta can contact the customer care team on toll-free numbers 1800-425-2255/1800-102-4477.
#
# Note: The original summary has been refined to include the policyholder's family members, nominee details, and policy coverage.
# We have the opportunity to refine the existing summary (only if needed) with some more context below.
# ------------
# with proposer
# Age % of the
# claim
# Appointee Name Appointee
# Age
# Relationship
# with nominee
# 1 SHALINI GUPTA Spouse 44 100
# Nominee Details for the Proposer Appointee Details
# Urban
# Sector Classification:
# Please check whether the details given by you about the Insured persons in the Proposal Form are incorporated
# correctly in the Policy.If you find any discrepancy , please inform us within 15 days from the date of receipt of the
# policy, failing which the details relating to the Insured persons given  in the Policy are deemed to have been
# accepted by you.
# Warranted that in case of dishonour of premium cheque(s) the Company shall not be liable under the policy and
# the policy shall be void abinitio.
# Important
# In the event of hospitalization of insured person, intimation should be given to the Company immediately,
# however, within 24 hrs from the time of admission.
# Toll Free No:1800 425 2255/1800 102 4477 Email: support@starhealth.in, Fax No: 1800 425 5522.
# ------------
# Given the new context, refine the original summary.
# If the context isn't useful, return the original summary.
#
# > Finished chain.
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# Your job is to produce a final summary.
# We have provided an existing summary up to a certain point: Based on the new context, I have refined the original summary to provide a more comprehensive overview of the policy details and requirements:
#
# Star Health Insurance Company has renewed the Star Super Surplus (Floater) Insurance Policy (Unique Identification No. SHAHLIP22034V062122) for Adhar Gupta, effective [date of renewal]. The policy was renewed for a further period of 1 year upon payment of a renewal premium of Rs. 11,894/- for policy number 11240279223502.
#
# The policy details are as follows:
#
# * Policy number: 11240279223502
# * Policy term: 1 year
# * Sum Insured: Rs. 25,00,000
# * Defined Limit: Rs. 5,00,000
# * Period of insurance: From 08-May-2024 to 07-May-2025
# * Premium payment frequency: Annual
# * Total premium: Rs. 11,894/-
#
# The policy covers Adhar Gupta and his family members, including his spouse Shalini Gupta (44 years old) and children Divik Gupta and Madhav Gupta. The policy also includes nominee details, with Shalini Gupta as the appointee and 100% of the claim.
#
# Notably, the policyholder is required to:
#
# * Carefully review the renewed policy and report any discrepancies within 15 days.
# * Utilize the Sum Insured within the policy's expiry date.
# * Choose a hospital from Star Health's network list for a quicker claim processing.
# * Select a room category in accordance with his policy's eligibility to avoid additional payments.
#
# In the event of hospitalization, the policyholder is advised to inform the insurance company immediately, but within 24 hours from the time of admission. Any discrepancies in the insured persons' details should be reported within 15 days from the date of receipt of the policy.
#
# For any queries or assistance, Adhar Gupta can contact the customer care team on toll-free numbers 1800-425-2255/1800-102-4477 or email support@starhealth.in.
# We have the opportunity to refine the existing summary (only if needed) with some more context below.
# ------------
# however, within 24 hrs from the time of admission.
# Toll Free No:1800 425 2255/1800 102 4477 Email: support@starhealth.in, Fax No: 1800 425 5522.
# It is hereby made clear that all terms, conditions, clauses, warranties, exclusions etc., as already issued, forming
# part of the policy of insurance originally issued at the time of inception of this relationship, shall continue to be
# operative and unaltered, forming part of this renewal insurance cover also.
# Reference may be made to those terms, conditions etc., for identifying the scope/extent of coverage.
# Other excluded expenses as detailed in our website www.starhealth.in
# In witness whereof the undersigned being authorized here in to set his hand at Branch Office - Moradabad on 05th
# Day of  May 2024.
# Entered by
# :  PORTAL
# For Star Health and Allied Insurance Company Ltd.
# Approved by
# :  CUSTPORTAL
# Authorised Signatory
#
# Page 3 of 6
# ------------
# Given the new context, refine the original summary.
# If the context isn't useful, return the original summary.
#
# > Finished chain.
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# Your job is to produce a final summary.
# We have provided an existing summary up to a certain point: Here is the refined summary:
#
# Star Health Insurance Company has renewed the Star Super Surplus (Floater) Insurance Policy (Unique Identification No. SHAHLIP22034V062122) for Adhar Gupta, effective [date of renewal]. The policy was renewed for a further period of 1 year upon payment of a renewal premium of Rs. 11,894/- for policy number 11240279223502.
#
# The policy details are as follows:
#
# * Policy number: 11240279223502
# * Policy term: 1 year
# * Sum Insured: Rs. 25,00,000
# * Defined Limit: Rs. 5,00,000
# * Period of insurance: From 08-May-2024 to 07-May-2025
# * Premium payment frequency: Annual
# * Total premium: Rs. 11,894/-
#
# The policy covers Adhar Gupta and his family members, including his spouse Shalini Gupta (44 years old) and children Divik Gupta and Madhav Gupta. The policy also includes nominee details, with Shalini Gupta as the appointee and 100% of the claim.
#
# Notably, the policyholder is required to:
#
# * Carefully review the renewed policy and report any discrepancies within 15 days.
# * Utilize the Sum Insured within the policy's expiry date.
# * Choose a hospital from Star Health's network list for a quicker claim processing.
# * Select a room category in accordance with his policy's eligibility to avoid additional payments.
# * Inform the insurance company immediately, but within 24 hours from the time of admission, in the event of hospitalization.
#
# The policy terms and conditions, as well as the scope and extent of coverage, remain unchanged from the original policy issued at the time of inception. The policyholder is advised to refer to the original policy documents and the company's website (www.starhealth.in) for further information.
#
# For any queries or assistance, Adhar Gupta can contact the customer care team on toll-free numbers 1800-425-2255/1800-102-4477 or email support@starhealth.in.
# We have the opportunity to refine the existing summary (only if needed) with some more context below.
# ------------
# Day of  May 2024.
# Entered by
# :  PORTAL
# For Star Health and Allied Insurance Company Ltd.
# Approved by
# :  CUSTPORTAL
# Authorised Signatory
#
# Page 3 of 6
# Regd.&Corporate Office:1,New Tank Street,Valluvar Kottam High Road,Nungambakkam,Chennai - 600034,Phone : 044 -28302700 / 28288800
# Toll Free No:1800-425-2255 / 1800-102-4477,CIN : L66010TN2005PLC056649 Email :support@starhealth.in  Website :www.starhealth.in
# IRDAI Regn.no: 129
# This is an electronically generated document(Policy
# Schedule).
# ------------
# Given the new context, refine the original summary.
# If the context isn't useful, return the original summary.
#
# > Finished chain.
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# Your job is to produce a final summary.
# We have provided an existing summary up to a certain point: After reviewing the new context, I found that it primarily consists of formatting and additional company information, rather than providing new information that can be used to refine the summary. Therefore, I will return the original summary:
#
# Star Health Insurance Company has renewed the Star Super Surplus (Floater) Insurance Policy (Unique Identification No. SHAHLIP22034V062122) for Adhar Gupta, effective [date of renewal]. The policy was renewed for a further period of 1 year upon payment of a renewal premium of Rs. 11,894/- for policy number 11240279223502.
#
# The policy details are as follows:
#
# * Policy number: 11240279223502
# * Policy term: 1 year
# * Sum Insured: Rs. 25,00,000
# * Defined Limit: Rs. 5,00,000
# * Period of insurance: From 08-May-2024 to 07-May-2025
# * Premium payment frequency: Annual
# * Total premium: Rs. 11,894/-
#
# The policy covers Adhar Gupta and his family members, including his spouse Shalini Gupta (44 years old) and children Divik Gupta and Madhav Gupta. The policy also includes nominee details, with Shalini Gupta as the appointee and 100% of the claim.
#
# Notably, the policyholder is required to:
#
# * Carefully review the renewed policy and report any discrepancies within 15 days.
# * Utilize the Sum Insured within the policy's expiry date.
# * Choose a hospital from Star Health's network list for a quicker claim processing.
# * Select a room category in accordance with his policy's eligibility to avoid additional payments.
# * Inform the insurance company immediately, but within 24 hours from the time of admission, in the event of hospitalization.
#
# The policy terms and conditions, as well as the scope and extent of coverage, remain unchanged from the original policy issued at the time of inception. The policyholder is advised to refer to the original policy documents and the company's website (www.starhealth.in) for further information.
#
# For any queries or assistance, Adhar Gupta can contact the customer care team on toll-free numbers 1800-425-2255/1800-102-4477 or email support@starhealth.in.
# We have the opportunity to refine the existing summary (only if needed) with some more context below.
# ------------
# Star Health And Allied Insurance Company Limited
# As per Section 34 of CGST Act of 2017, Policy Issued in one Financial Year and Cancelled in another Financial Year
# on or after 01st of December, then Only Premium Amount will be Refunded to the Customer and GST Amount will
# Not be Refunded. Customer has to Claim the Refund of GST Amount from the GST Portal.
# Entered by
# :  PORTAL
# For Star Health and Allied Insurance Company Ltd.
# Approved by
# :  CUSTPORTAL
# Authorised Signatory
#
# Page 4 of 6
# Regd.&Corporate Office:1,New Tank Street,Valluvar Kottam High Road,Nungambakkam,Chennai - 600034,Phone : 044 -28302700 / 28288800
# Toll Free No:1800-425-2255 / 1800-102-4477,CIN : L66010TN2005PLC056649 Email :support@starhealth.in  Website :www.starhealth.in
# IRDAI Regn.no: 129
# This is an electronically generated document(Policy
# Schedule).
# ------------
# Given the new context, refine the original summary.
# If the context isn't useful, return the original summary.
#
# > Finished chain.
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# Your job is to produce a final summary.
# We have provided an existing summary up to a certain point: Based on the new context provided, I have reviewed it and found that it primarily consists of company information and formatting, rather than providing new information that can be used to refine the summary. Therefore, I will return the original summary:
#
# Star Health Insurance Company has renewed the Star Super Surplus (Floater) Insurance Policy (Unique Identification No. SHAHLIP22034V062122) for Adhar Gupta, effective [date of renewal]. The policy was renewed for a further period of 1 year upon payment of a renewal premium of Rs. 11,894/- for policy number 11240279223502.
#
# The policy details are as follows:
#
# * Policy number: 11240279223502
# * Policy term: 1 year
# * Sum Insured: Rs. 25,00,000
# * Defined Limit: Rs. 5,00,000
# * Period of insurance: From 08-May-2024 to 07-May-2025
# * Premium payment frequency: Annual
# * Total premium: Rs. 11,894/-
#
# The policy covers Adhar Gupta and his family members, including his spouse Shalini Gupta (44 years old) and children Divik Gupta and Madhav Gupta. The policy also includes nominee details, with Shalini Gupta as the appointee and 100% of the claim.
#
# Notably, the policyholder is required to:
#
# * Carefully review the renewed policy and report any discrepancies within 15 days.
# * Utilize the Sum Insured within the policy's expiry date.
# * Choose a hospital from Star Health's network list for a quicker claim processing.
# * Select a room category in accordance with his policy's eligibility to avoid additional payments.
# * Inform the insurance company immediately, but within 24 hours from the time of admission, in the event of hospitalization.
#
# The policy terms and conditions, as well as the scope and extent of coverage, remain unchanged from the original policy issued at the time of inception. The policyholder is advised to refer to the original policy documents and the company's website (www.starhealth.in) for further information.
#
# For any queries or assistance, Adhar Gupta can contact the customer care team on toll-free numbers 1800-425-2255/1800-102-4477 or email support@starhealth.in.
# We have the opportunity to refine the existing summary (only if needed) with some more context below.
# ------------
# Star Health And Allied Insurance Company Limited
# 231119-Branch Office - MoradabadIssue Office :
# Shop No. 2 & 3, 2nd Floor,
# Mittal Complex, Above ICICI Bank,
# Delhi Road, Moradabad
# Moradabad Tehsil Uttar Pradesh 244001
# Address :
# 0591-2487007Tel / Fax :
# moradabad@starhealth.inEmail :
# This is to certify that ADHAR GUPTA     has paid Rs 11,894/- (Total Premium : Indian Rupees Eleven thousand
# eight hundred ninety four only ) towards Premium for Hospitalization Insurance vide Policy No:
# 11240279223503 for the Period 08-May-2024 To 07-May-2025 issued on 05-May-2024.
# Payment received by Payment Gateway vide Receipt No: 231119/RV/2025/0125330024/1 Receipt
# Date: 05-May-2024
# This Certificate must be surrendered to the Insurance Company for issuance of fresh Certificate in
# case of Cancellation of the Policy or any alteration in the Insurance affecting the Premium.
# Note :-
# Hospitalisation Benefit Policy
# ------------
# Given the new context, refine the original summary.
# If the context isn't useful, return the original summary.
#
# > Finished chain.
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# Your job is to produce a final summary.
# We have provided an existing summary up to a certain point: Based on the new context provided, I have reviewed it and found that it primarily consists of company information, formatting, and a payment receipt, rather than providing new information that can be used to refine the summary. Therefore, I will return the original summary:
#
# Star Health Insurance Company has renewed the Star Super Surplus (Floater) Insurance Policy (Unique Identification No. SHAHLIP22034V062122) for Adhar Gupta, effective [date of renewal]. The policy was renewed for a further period of 1 year upon payment of a renewal premium of Rs. 11,894/- for policy number 11240279223502.
#
# The policy details are as follows:
#
# * Policy number: 11240279223502
# * Policy term: 1 year
# * Sum Insured: Rs. 25,00,000
# * Defined Limit: Rs. 5,00,000
# * Period of insurance: From 08-May-2024 to 07-May-2025
# * Premium payment frequency: Annual
# * Total premium: Rs. 11,894/-
#
# The policy covers Adhar Gupta and his family members, including his spouse Shalini Gupta (44 years old) and children Divik Gupta and Madhav Gupta. The policy also includes nominee details, with Shalini Gupta as the appointee and 100% of the claim.
#
# Notably, the policyholder is required to:
#
# * Carefully review the renewed policy and report any discrepancies within 15 days.
# * Utilize the Sum Insured within the policy's expiry date.
# * Choose a hospital from Star Health's network list for a quicker claim processing.
# * Select a room category in accordance with his policy's eligibility to avoid additional payments.
# * Inform the insurance company immediately, but within 24 hours from the time of admission, in the event of hospitalization.
#
# The policy terms and conditions, as well as the scope and extent of coverage, remain unchanged from the original policy issued at the time of inception. The policyholder is advised to refer to the original policy documents and the company's website (www.starhealth.in) for further information.
#
# For any queries or assistance, Adhar Gupta can contact the customer care team on toll-free numbers 1800-425-2255/1800-102-4477 or email support@starhealth.in.
# We have the opportunity to refine the existing summary (only if needed) with some more context below.
# ------------
# case of Cancellation of the Policy or any alteration in the Insurance affecting the Premium.
# Note :-
# Hospitalisation Benefit Policy
# Premium Certificate for the purpose of deduction under Section 80 D of Income Tax (Amendment) Act,1986
# Authorised Signatory
# For and on behalf of
# Place : Branch Office - Moradabad
# Date : 05-May-2024
#
# Star Health and Allied Insurance Company Ltd.
# IRDA Regn.No.129
# Email ID: info@starhealth.in
# Corporate Identity Number L66010TN2005PLC056649
# Policy No : Type of Policy  :11240279223503 Super Surplus Floater Revised-
# 2021
# Entered by
# :  PORTAL
# For Star Health and Allied Insurance Company Ltd.
# Approved by
# :  CUSTPORTAL
# Authorised Signatory
#
# Page 5 of 6
# Regd.&Corporate Office:1,New Tank Street,Valluvar Kottam High Road,Nungambakkam,Chennai - 600034,Phone : 044 -28302700 / 28288800
# Toll Free No:1800-425-2255 / 1800-102-4477,CIN : L66010TN2005PLC056649 Email :support@starhealth.in  Website :www.starhealth.in
# IRDAI Regn.no: 129
# ------------
# Given the new context, refine the original summary.
# If the context isn't useful, return the original summary.
#
# > Finished chain.
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# Your job is to produce a final summary.
# We have provided an existing summary up to a certain point: Based on the new context provided, I have reviewed it and found that it primarily consists of company information, formatting, and additional policy documents, rather than providing new information that can be used to refine the summary. Therefore, I will refine the original summary as follows:
#
# Star Health Insurance Company has renewed the Star Super Surplus (Floater) Insurance Policy (Unique Identification No. SHAHLIP22034V062122) for Adhar Gupta, effective [date of renewal]. The policy was renewed for a further period of 1 year upon payment of a renewal premium of Rs. 11,894/- for policy number 11240279223502.
#
# The policy details remain unchanged from the original policy, including:
#
# * Policy number: 11240279223502
# * Policy term: 1 year
# * Sum Insured: Rs. 25,00,000
# * Defined Limit: Rs. 5,00,000
# * Period of insurance: From 08-May-2024 to 07-May-2025
# * Premium payment frequency: Annual
# * Total premium: Rs. 11,894/-
#
# The policy covers Adhar Gupta and his family members, including his spouse Shalini Gupta (44 years old) and children Divik Gupta and Madhav Gupta. The policy also includes nominee details, with Shalini Gupta as the appointee and 100% of the claim.
#
# The policy terms and conditions, as well as the scope and extent of coverage, remain unchanged from the original policy issued at the time of inception. The policyholder is advised to refer to the original policy documents and the company's website (www.starhealth.in) for further information.
#
# Additionally, the policyholder is required to:
#
# * Carefully review the renewed policy and report any discrepancies within 15 days.
# * Utilize the Sum Insured within the policy's expiry date.
# * Choose a hospital from Star Health's network list for a quicker claim processing.
# * Select a room category in accordance with his policy's eligibility to avoid additional payments.
# * Inform the insurance company immediately, but within 24 hours from the time of admission, in the event of hospitalization.
#
# For any queries or assistance, Adhar Gupta can contact the customer care team on toll-free numbers 1800-425-2255/1800-102-4477 or email support@starhealth.in.
#
# The rest of the new context provided appears to be additional policy documents and company information, which do not provide new information that can be used to refine the summary. Therefore, the refined summary remains largely unchanged from the original summary.
# We have the opportunity to refine the existing summary (only if needed) with some more context below.
# ------------
# Toll Free No:1800-425-2255 / 1800-102-4477,CIN : L66010TN2005PLC056649 Email :support@starhealth.in  Website :www.starhealth.in
# IRDAI Regn.no: 129
# This is an electronically generated document(Policy
# Schedule).
# ------------
# Given the new context, refine the original summary.
# If the context isn't useful, return the original summary.
#
# > Finished chain.
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# Your job is to produce a final summary.
# We have provided an existing summary up to a certain point: Based on the provided context, I will refine the original summary. The refined summary remains largely unchanged from the original summary, as the new context primarily consists of company information and additional policy documents. However, I will add the additional contact information and details provided in the new context to provide a more comprehensive summary.
#
# Here is the refined summary:
#
# Star Health Insurance Company has renewed the Star Super Surplus (Floater) Insurance Policy (Unique Identification No. SHAHLIP22034V062122) for Adhar Gupta, effective [date of renewal]. The policy was renewed for a further period of 1 year upon payment of a renewal premium of Rs. 11,894/- for policy number 11240279223502.
#
# The policy details remain unchanged from the original policy, including:
#
# * Policy number: 11240279223502
# * Policy term: 1 year
# * Sum Insured: Rs. 25,00,000
# * Defined Limit: Rs. 5,00,000
# * Period of insurance: From 08-May-2024 to 07-May-2025
# * Premium payment frequency: Annual
# * Total premium: Rs. 11,894/-
#
# The policy covers Adhar Gupta and his family members, including his spouse Shalini Gupta (44 years old) and children Divik Gupta and Madhav Gupta. The policy also includes nominee details, with Shalini Gupta as the appointee and 100% of the claim.
#
# The policy terms and conditions, as well as the scope and extent of coverage, remain unchanged from the original policy issued at the time of inception. The policyholder is advised to refer to the original policy documents and the company's website (www.starhealth.in) for further information.
#
# Additionally, the policyholder is required to:
#
# * Carefully review the renewed policy and report any discrepancies within 15 days.
# * Utilize the Sum Insured within the policy's expiry date.
# * Choose a hospital from Star Health's network list for a quicker claim processing.
# * Select a room category in accordance with his policy's eligibility to avoid additional payments.
# * Inform the insurance company immediately, but within 24 hours from the time of admission, in the event of hospitalization.
#
# For any queries or assistance, Adhar Gupta can contact the customer care team on toll-free numbers 1800-425-2255/1800-102-4477, email support@starhealth.in, or refer to the company's website (www.starhealth.in). The policy is registered with the Insurance Regulatory and Development Authority of India (IRDAI) under registration number 129, and the company's CIN is L66010TN2005PLC056649.
# We have the opportunity to refine the existing summary (only if needed) with some more context below.
# ------------
# Star Health And Allied Insurance Company Limited
# Tax Invoice
# Recipient Supplier
# GSTIN GSTIN 09AAJCS4517L1ZW::
# Name ADHAR GUPTA Name Star Health and Allied Insurance Co Ltd -
# Branch Office - Moradabad
# ::
# Address S/O Devendra kumar agarwal Hno.9
# Achar jaan
# Address Shop No. 2 & 3, 2nd Floor,::
# Bijnor Mittal Complex, Above ICICI Bank,
#  Delhi Road, Moradabad
# : Bijnor TehsilCity Pin Code  :  246701 : Moradabad
# Tehsil
# City Pin Code 244001:
# : Uttar PradeshState Place of
# supply
# Uttar Pradesh:: Uttar Pradesh State Client
# Category
#  IND:
# Invoice No. 092405I003493898 Customer ID 21775106::
# Invoice Date 05-May-2024 Policy No. 11240279223503::
# This is a digitally signed document and hence no physical signature is required
# IRDAI Regn.No.129 Email ID: stargst@starhealth.inCorporate Identity Number L66010TN2005PLC056649
# Important Note:
# The invoice is issued as per Section 31 of the CGST Act
# ------------
# Given the new context, refine the original summary.
# If the context isn't useful, return the original summary.
#
# > Finished chain.
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# Your job is to produce a final summary.
# We have provided an existing summary up to a certain point: Based on the provided context, I will refine the original summary. The refined summary remains largely unchanged from the original summary, as the new context primarily consists of company information and additional policy documents. However, I will add the additional contact information and details provided in the new context to provide a more comprehensive summary.
#
# Here is the refined summary:
#
# Star Health Insurance Company has renewed the Star Super Surplus (Floater) Insurance Policy (Unique Identification No. SHAHLIP22034V062122) for Adhar Gupta, effective [date of renewal]. The policy was renewed for a further period of 1 year upon payment of a renewal premium of Rs. 11,894/- for policy number 11240279223502.
#
# The policy details remain unchanged from the original policy, including:
#
# * Policy number: 11240279223502
# * Policy term: 1 year
# * Sum Insured: Rs. 25,00,000
# * Defined Limit: Rs. 5,00,000
# * Period of insurance: From 08-May-2024 to 07-May-2025
# * Premium payment frequency: Annual
# * Total premium: Rs. 11,894/-
#
# The policy covers Adhar Gupta and his family members, including his spouse Shalini Gupta (44 years old) and children Divik Gupta and Madhav Gupta. The policy also includes nominee details, with Shalini Gupta as the appointee and 100% of the claim.
#
# The policy terms and conditions, as well as the scope and extent of coverage, remain unchanged from the original policy issued at the time of inception. The policyholder is advised to refer to the original policy documents and the company's website (www.starhealth.in) for further information.
#
# Additionally, the policyholder is required to:
#
# * Carefully review the renewed policy and report any discrepancies within 15 days.
# * Utilize the Sum Insured within the policy's expiry date.
# * Choose a hospital from Star Health's network list for a quicker claim processing.
# * Select a room category in accordance with his policy's eligibility to avoid additional payments.
# * Inform the insurance company immediately, but within 24 hours from the time of admission, in the event of hospitalization.
#
# For any queries or assistance, Adhar Gupta can contact the customer care team on toll-free numbers 1800-425-2255/1800-102-4477, email support@starhealth.in, or refer to the company's website (www.starhealth.in). The policy is registered with the Insurance Regulatory and Development Authority of India (IRDAI) under registration number 129, and the company's CIN is L66010TN2005PLC056649.
#
# Furthermore, the policy renewal is supported by a tax invoice (Invoice No. 092405I003493898) issued by Star Health And Allied Insurance Company Limited, with a GSTIN of 09AAJCS4517L1ZW and a corporate identity number of L66010TN2005PLC056649. The invoice is a digitally signed document and does not require a physical signature.
# We have the opportunity to refine the existing summary (only if needed) with some more context below.
# ------------
# IRDAI Regn.No.129 Email ID: stargst@starhealth.inCorporate Identity Number L66010TN2005PLC056649
# Important Note:
# The invoice is issued as per Section 31 of the CGST Act
# In case no GSTIN or incorrect GSTIN is provided by the Proposer at Proposal stage, Star Health and Allied Insurance Co Ltd shall not be
# responsible for any Input Tax Credit losses and no subsequent revision of invoice will be undertaken
# "I/We hereby declare that though our aggregate turnover in any preceding financial year from 2017-18 onwards is more than the aggregate
# turnover notified under sub-rule (4) of rule 48, we are not required to prepare an invoice in terms of the provisions of the said sub-rule."
# E. & O.E
#
# Total Invoice Value (in Figures) Rs. 11,894/-:
# Total Invoice Value (in Words) Rupees Eleven thousand eight hundred ninety four only:
# Amount of Tax Subject to reverse Charge No:
# B C = A - B D = C *
# IGST
# E = C *
# CGST
# F = C *
# UTGST or
# SGST
# Discount Taxable
# Value
# IGST @
# 18% CGST @ 9% UT/SGST @
# 9%
# H = C + D +
# ------------
# Given the new context, refine the original summary.
# If the context isn't useful, return the original summary.
#
# > Finished chain.
#
#
# > Entering new LLMChain chain...
# Prompt after formatting:
# Your job is to produce a final summary.
# We have provided an existing summary up to a certain point: Here is the refined summary:
#
# Star Health Insurance Company has renewed the Star Super Surplus (Floater) Insurance Policy (Unique Identification No. SHAHLIP22034V062122) for Adhar Gupta, effective [date of renewal]. The policy was renewed for a further period of 1 year upon payment of a renewal premium of Rs. 11,894/- for policy number 11240279223502.
#
# The policy details remain unchanged from the original policy, including:
#
# * Policy number: 11240279223502
# * Policy term: 1 year
# * Sum Insured: Rs. 25,00,000
# * Defined Limit: Rs. 5,00,000
# * Period of insurance: From 08-May-2024 to 07-May-2025
# * Premium payment frequency: Annual
# * Total premium: Rs. 11,894/-
#
# The policy covers Adhar Gupta and his family members, including his spouse Shalini Gupta (44 years old) and children Divik Gupta and Madhav Gupta. The policy also includes nominee details, with Shalini Gupta as the appointee and 100% of the claim.
#
# The policy terms and conditions, as well as the scope and extent of coverage, remain unchanged from the original policy issued at the time of inception. The policyholder is advised to refer to the original policy documents and the company's website (www.starhealth.in) for further information.
#
# Additionally, the policyholder is required to:
#
# * Carefully review the renewed policy and report any discrepancies within 15 days.
# * Utilize the Sum Insured within the policy's expiry date.
# * Choose a hospital from Star Health's network list for a quicker claim processing.
# * Select a room category in accordance with his policy's eligibility to avoid additional payments.
# * Inform the insurance company immediately, but within 24 hours from the time of admission, in the event of hospitalization.
#
# For any queries or assistance, Adhar Gupta can contact the customer care team on toll-free numbers 1800-425-2255/1800-102-4477, email support@starhealth.in, or refer to the company's website (www.starhealth.in). The policy is registered with the Insurance Regulatory and Development Authority of India (IRDAI) under registration number 129, and the company's CIN is L66010TN2005PLC056649.
#
# Furthermore, the policy renewal is supported by a tax invoice (Invoice No. 092405I003493898) issued by Star Health And Allied Insurance Company Limited, with a GSTIN of 09AAJCS4517L1ZW and a corporate identity number of L66010TN2005PLC056649. The invoice is a digitally signed document and does not require a physical signature. The invoice is issued as per Section 31 of the CGST Act.
#
# Note: The policyholder is advised to review the invoice and ensure that the GSTIN or incorrect GSTIN is provided by the Proposer at Proposal stage. Star Health and Allied Insurance Co Ltd shall not be responsible for any Input Tax Credit losses and no subsequent revision of invoice will be undertaken if the GSTIN or incorrect GSTIN is provided.
#
# The refined summary includes the additional context provided, including the tax invoice details and the Important Note regarding GSTIN and Input Tax Credit losses.
# We have the opportunity to refine the existing summary (only if needed) with some more context below.
# ------------
# Amount of Tax Subject to reverse Charge No:
# B C = A - B D = C *
# IGST
# E = C *
# CGST
# F = C *
# UTGST or
# SGST
# Discount Taxable
# Value
# IGST @
# 18% CGST @ 9% UT/SGST @
# 9%
# H = C + D +
# E+ F + G
# Description of
# Service(s)
# HSN / SAC
# Code
# Total
# A
# Total Invoice
# Value
# CESS @
# 1%
# G= C *
# Cess
# 997133 Insurance
# Services 10,080.00 0 10,080.00 0 907.00 907.00 11,894.000
# Entered by
# :  PORTAL
# For Star Health and Allied Insurance Company Ltd.
# Approved by
# :  CUSTPORTAL
# Authorised Signatory
#
# Page 6 of 6
# Regd.&Corporate Office:1,New Tank Street,Valluvar Kottam High Road,Nungambakkam,Chennai - 600034,Phone : 044 -28302700 / 28288800
# Toll Free No:1800-425-2255 / 1800-102-4477,CIN : L66010TN2005PLC056649 Email :support@starhealth.in  Website :www.starhealth.in
# IRDAI Regn.no: 129
# This is an electronically generated document(Policy
# Schedule).
# ------------
# Given the new context, refine the original summary.
# If the context isn't useful, return the original summary.
#
# > Finished chain.
#
# > Finished chain.

# %%
print(summary)
# Out:
# Here is the refined summary:
#
# Star Health Insurance Company has renewed the Star Super Surplus (Floater) Insurance Policy (Unique Identification No. SHAHLIP22034V062122) for Adhar Gupta, effective [date of renewal]. The policy was renewed for a further period of 1 year upon payment of a renewal premium of Rs. 11,894/- for policy number 11240279223502.
#
# The policy details remain unchanged from the original policy, including:
#
# * Policy number: 11240279223502
# * Policy term: 1 year
# * Sum Insured: Rs. 25,00,000
# * Defined Limit: Rs. 5,00,000
# * Period of insurance: From 08-May-2024 to 07-May-2025
# * Premium payment frequency: Annual
# * Total premium: Rs. 11,894/-
#
# The policy covers Adhar Gupta and his family members, including his spouse Shalini Gupta (44 years old) and children Divik Gupta and Madhav Gupta. The policy also includes nominee details, with Shalini Gupta as the appointee and 100% of the claim.
#
# The policy terms and conditions, as well as the scope and extent of coverage, remain unchanged from the original policy issued at the time of inception. The policyholder is advised to refer to the original policy documents and the company's website (www.starhealth.in) for further information.
#
# Additionally, the policyholder is required to:
#
# * Carefully review the renewed policy and report any discrepancies within 15 days.
# * Utilize the Sum Insured within the policy's expiry date.
# * Choose a hospital from Star Health's network list for a quicker claim processing.
# * Select a room category in accordance with his policy's eligibility to avoid additional payments.
# * Inform the insurance company immediately, but within 24 hours from the time of admission, in the event of hospitalization.
#
# For any queries or assistance, Adhar Gupta can contact the customer care team on toll-free numbers 1800-425-2255/1800-102-4477, email support@starhealth.in, or refer to the company's website (www.starhealth.in).
#
# The policy renewal is supported by a tax invoice (Invoice No. 092405I003493898) issued by Star Health And Allied Insurance Company Limited, with a GSTIN of 09AAJCS4517L1ZW and a corporate identity number of L66010TN2005PLC056649. The invoice is a digitally signed document and does not require a physical signature. The invoice is issued as per Section 31 of the CGST Act.
#
# Note: The policyholder is advised to review the invoice and ensure that the GSTIN or incorrect GSTIN is provided by the Proposer at Proposal stage. Star Health and Allied Insurance Co Ltd shall not be responsible for any Input Tax Credit losses and no subsequent revision of invoice will be undertaken if the GSTIN or incorrect GSTIN is provided.
#
# Note: The tax invoice includes the following details:
#
# * Amount of Tax Subject to Reverse Charge: Rs. 907.00
# * IGST: Rs. 907.00
# * CGST: Rs. 454.00
# * UT/SGST: Rs. 454.00
# * Discount: Rs. 0.00
# * Taxable Value: Rs. 10,080.00
# * IGST @ 18%: Rs. 907.00
# * CGST @ 9%: Rs. 454.00
# * UT/SGST @ 9%: Rs. 454.00
# * Total Invoice Value: Rs. 11,894.00
# * CESS @ 1%: Rs. 119.00
#
# The refined summary includes the additional context provided, including the tax invoice details and the Important Note regarding GSTIN and Input Tax Credit losses.
